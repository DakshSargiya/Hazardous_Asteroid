# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime as dt

# %%
#Read and store the dataset
df = pd.read_csv('dataset.csv')
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#       Name  Epoch Date Close Approach Relative Velocity km per sec  \
# 0  3703080               7.889470e+11                    Very Slow
# 1  3723955                        NaN                         Slow
# 2  2446862               7.895520e+11                          NaN
# 3  3092506               7.901570e+11                    Very Slow
# 4  3514799               7.901570e+11                    Very Slow
#
#    Relative Velocity km per hr  Miles per hour  Miss Dist.(Astronomical)  \
# 0                  22017.00380     13680.50994                  0.419483
# 1                  65210.34609     40519.17311                       NaN
# 2                  27326.56018     16979.66180                  0.050956
# 3                  40225.94819     24994.83986                       NaN
# 4                  35426.99179             NaN                  0.407832
#
#    Miss Dist.(lunar)  Miss Dist.(kilometers)  Miss Dist.(miles)  \
# 0         163.178711              62753692.0         38993336.0
# 1                NaN              57298148.0         35603420.0
# 2          19.821890               7622911.5          4736657.5
# 3                NaN                     NaN         26522368.0
# 4         158.646713              61010824.0                NaN
#
#    Jupiter Tisserand Invariant  Epoch Osculation  Semi Major Axis  \
# 0                          NaN               NaN         1.407011
# 1                          NaN         2458000.5         1.107776
# 2                        4.557         2458000.5         1.458824
# 3                        5.093         2458000.5              NaN
# 4                        5.154               NaN         1.225615
#
#    Asc Node Longitude  Perihelion Arg  Aphelion Dist  Perihelion Time  \
# 0          314.373913       57.257470       2.005764              NaN
# 1          136.717242             NaN       1.497352      2457794.969
# 2          259.475979      248.415038       1.966857      2458120.468
# 3           57.173266             NaN       1.527904      2457902.337
# 4           84.629307      158.263596            NaN      2457814.455
#
#    Mean Anomaly  Mean Motion  approach_year  approach_month  approach_day  \
# 0    264.837533     0.590551            NaN             1.0           1.0
# 1    173.741112     0.845330         1995.0             1.0           1.0
# 2           NaN          NaN         1995.0             NaN           8.0
# 3     68.741007     0.700277         1995.0             NaN          15.0
# 4           NaN          NaN            NaN             NaN          15.0
#
#   Orbital Period Orbit Uncertainity  Hazardous
# 0            Low             Medium       True
# 1            Low                NaN      False
# 2         Medium                NaN       True
# 3            Low             Medium      False
# 4            NaN                Low       True

# %%
df[abs(df['Relative Velocity km per hr']*0.621371-df['Miles per hour'])>2].Name
#From this we can say that the conversions used are correct and have a very less error margin
# Out:
# Series([], Name: Name, dtype: int64)

# %%
#Fill the Nan values of relative velocity by back conversion
df['Relative Velocity km per hr']=df['Relative Velocity km per hr'].fillna(df['Miles per hour']/0.621371)

# %%
rel_grp_df= df.groupby('Relative Velocity km per sec')[['Relative Velocity km per hr']].mean()
rel_grp_df
# Out:
#                               Relative Velocity km per hr
# Relative Velocity km per sec
# Fast                                         94548.457472
# Slow                                         57819.095395
# Very Fast                                   133550.964259
# Very Slow                                    26987.390474

# %%
#Now we again fill the empty values of relative velocity km per hr using these values
df.loc[(df['Relative Velocity km per hr'].isna()) & (df['Relative Velocity km per sec'] == 'Fast'), 'Relative Velocity km per hr'] = 94548.457472
df.loc[(df['Relative Velocity km per hr'].isna()) & (df['Relative Velocity km per sec'] == 'Slow'), 'Relative Velocity km per hr'] = 57819.095395
df.loc[(df['Relative Velocity km per hr'].isna()) & (df['Relative Velocity km per sec'] == 'Very Fast'), 'Relative Velocity km per hr'] = 133550.96426
df.loc[(df['Relative Velocity km per hr'].isna()) & (df['Relative Velocity km per sec'] == 'Very Slow'), 'Relative Velocity km per hr'] = 26987.390474

# %%
#A similar logic can be applied to fill the missing values of MissDistance(KM)
df['Miss Dist.(kilometers)'] = df['Miss Dist.(kilometers)'].fillna(df['Miss Dist.(Astronomical)']*149597871)
df['Miss Dist.(kilometers)'] = df['Miss Dist.(kilometers)'].fillna(df['Miss Dist.(lunar)']*384399)
df['Miss Dist.(kilometers)'] = df['Miss Dist.(kilometers)'].fillna(df['Miss Dist.(miles)']/0.621371)

# %%
#Now we can drop those unnecessary columns
df = df.drop(columns=['Relative Velocity km per sec','Miles per hour','Miss Dist.(Astronomical)','Miss Dist.(lunar)','Miss Dist.(miles)'])
df.head()
# Out:
#       Name  Epoch Date Close Approach  Relative Velocity km per hr  \
# 0  3703080               7.889470e+11                  22017.00380
# 1  3723955                        NaN                  65210.34609
# 2  2446862               7.895520e+11                  27326.56018
# 3  3092506               7.901570e+11                  40225.94819
# 4  3514799               7.901570e+11                  35426.99179
#
#    Miss Dist.(kilometers)  Jupiter Tisserand Invariant  Epoch Osculation  \
# 0            6.275369e+07                          NaN               NaN
# 1            5.729815e+07                          NaN         2458000.5
# 2            7.622912e+06                        4.557         2458000.5
# 3            4.268363e+07                        5.093         2458000.5
# 4            6.101082e+07                        5.154               NaN
#
#    Semi Major Axis  Asc Node Longitude  Perihelion Arg  Aphelion Dist  \
# 0         1.407011          314.373913       57.257470       2.005764
# 1         1.107776          136.717242             NaN       1.497352
# 2         1.458824          259.475979      248.415038       1.966857
# 3              NaN           57.173266             NaN       1.527904
# 4         1.225615           84.629307      158.263596            NaN
#
#    Perihelion Time  Mean Anomaly  Mean Motion  approach_year  approach_month  \
# 0              NaN    264.837533     0.590551            NaN             1.0
# 1      2457794.969    173.741112     0.845330         1995.0             1.0
# 2      2458120.468           NaN          NaN         1995.0             NaN
# 3      2457902.337     68.741007     0.700277         1995.0             NaN
# 4      2457814.455           NaN          NaN            NaN             NaN
#
#    approach_day Orbital Period Orbit Uncertainity  Hazardous
# 0           1.0            Low             Medium       True
# 1           1.0            Low                NaN      False
# 2           8.0         Medium                NaN       True
# 3          15.0            Low             Medium      False
# 4          15.0            NaN                Low       True

# %%
#Encode the categorical columns
df['Orbital Period'] = df['Orbital Period'].replace({'Low':0,'Medium':1,'High':2})
df['Orbit Uncertainity'] = df['Orbit Uncertainity'].replace({'Low':0,'Medium':1,'High':2})
df['Hazardous'] = df['Hazardous'].replace({False:0,True:1})
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_25968\2668644283.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Orbital Period'] = df['Orbital Period'].replace({'Low':0,'Medium':1,'High':2})
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_25968\2668644283.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Orbit Uncertainity'] = df['Orbit Uncertainity'].replace({'Low':0,'Medium':1,'High':2})
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_25968\2668644283.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Hazardous'] = df['Hazardous'].replace({False:0,True:1})

# %%
corr_mat = df.corr()
sns.heatmap(corr_mat,cmap= 'coolwarm')
plt.show()
#We see that Jupiter Tisserand and Semi major are inversely related

# %%
#universal gravitational Constant
G = 6.67430e-11
# Mass of the Sun (kg)
M_sun = 1.989e30 
df['Mean Motion']=df['Mean Motion']*np.pi/180      #Converting to radians
df['Semi Major Axis'] = df['Semi Major Axis'].fillna(6.5/df['Jupiter Tisserand Invariant'])
df['Semi Major Axis']= df['Semi Major Axis'].fillna(((G*M_sun/((df['Mean Motion']/(24*3600))**2))**(1/3))/149597870700)

# %% [markdown]
# # 2.Feature Engineering

# %% [markdown]
#  ## Time untill approach
#
# The epoch date close approach and the approach date, approach month, approach year represent the same thing.
#
# Since the data is sorted with respect to epoch date close approach we interpolate it linearly and convert it into date time format to find the approach date.
#
# We also find the time untill approach by the difference between approach date and current date.
# It is to be noted that the epoch time is given in ms.
#
# We then drop the used columns and the Epoch Osculation date as it represents the date when which the orbital parameters of the asteroid are computed and is of no use to us.

# %%
df['Epoch Date Close Approach'] = pd.to_datetime(df['Epoch Date Close Approach'],unit='ms')
df["Approach Date"]=df["Epoch Date Close Approach"].interpolate(method="linear")
df['Epoch Osculation'] = pd.to_datetime(df['Epoch Osculation'],unit='ms')
curr_date = pd.Timestamp.now()
df['Time Until Approach(days)'] = ( curr_date-df['Approach Date']).dt.days
df.drop(['Epoch Date Close Approach','Epoch Osculation','approach_year','approach_month','approach_day'], axis=1,inplace=True)
df.head()
# Out:
#       Name  Relative Velocity km per hr  Miss Dist.(kilometers)  \
# 0  3703080                  22017.00380            6.275369e+07
# 1  3723955                  65210.34609            5.729815e+07
# 2  2446862                  27326.56018            7.622912e+06
# 3  3092506                  40225.94819            4.268363e+07
# 4  3514799                  35426.99179            6.101082e+07
#
#    Jupiter Tisserand Invariant  Semi Major Axis  Asc Node Longitude  \
# 0                          NaN         1.407011          314.373913
# 1                          NaN         1.107776          136.717242
# 2                        4.557         1.458824          259.475979
# 3                        5.093         1.276262           57.173266
# 4                        5.154         1.225615           84.629307
#
#    Perihelion Arg  Aphelion Dist  Perihelion Time  Mean Anomaly  Mean Motion  \
# 0       57.257470       2.005764              NaN    264.837533     0.010307
# 1             NaN       1.497352      2457794.969    173.741112     0.014754
# 2      248.415038       1.966857      2458120.468           NaN          NaN
# 3             NaN       1.527904      2457902.337     68.741007     0.012222
# 4      158.263596            NaN      2457814.455           NaN          NaN
#
#    Orbital Period  Orbit Uncertainity  Hazardous       Approach Date  \
# 0             0.0                 1.0          1 1995-01-01 07:56:40
# 1             0.0                 NaN          0 1995-01-04 19:58:20
# 2             1.0                 NaN          1 1995-01-08 08:00:00
# 3             0.0                 1.0          0 1995-01-15 08:03:20
# 4             NaN                 0.0          1 1995-01-15 08:03:20
#
#    Time Until Approach(days)
# 0                      10884
# 1                      10880
# 2                      10877
# 3                      10870
# 4                      10870

# %% [markdown]
# ### Miss Distance vs. Semi-major axis

# %%
df['Miss Distance vs Semi Major Axis(AU)'] = (df['Miss Dist.(kilometers)'] /149597871)/ df['Semi Major Axis']

# %% [markdown]
# ### Eccentricity, Orbital Period, Orbital Velocity
# We used the following formulas:
# $$\text{Eccentricity} = \frac{\text{Aphelion Distance}}{\text{Semi-Major Axis}}-1$$
# $$\text{Orbital Period} = \frac{2 \pi \left(\text{Semi Major Axis}\right)^{1.5}}{\sqrt{G \times M_Sun}}$$
# $$\text{Orbital Velocity} = \frac{2 \pi \times \text{Semi Major Axis}}{\text{Orbital Period } }$$
# We also checked for eccentricity to be less than 1.

# %%
df['Eccentricity']= df['Aphelion Dist']/df['Semi Major Axis'] -1
df = df[(df['Eccentricity'] <= 1) | (df['Eccentricity'].isnull())]

# df['Orbital Period(s)'] = ((df['Semi Major Axis']*149597870700)**(1.5))*1.72/(10**9.5)
df['Orbital Period(s)'] = ((df['Semi Major Axis']*149597870700)**(1.5))*2*np.pi/((G*M_sun)**0.5)
df['Orbital Period(s)']/=(60*60*24)
df.rename(columns={'Orbital Period(s)':'Orbital Period(days)'},inplace=True)

df.groupby('Orbital Period')[['Orbital Period(days)']].mean()
# Out:
#                 Orbital Period(days)
# Orbital Period
# 0.0                       412.060621
# 1.0                       790.491667
# 2.0                      1216.356553

# %% [markdown]
# ###### Since we have the categorical data of Orbital Period we fill the null values with the mean of the corresponding category

# %%
df.loc[(df['Orbital Period(days)'].isna()) & (df['Orbital Period'] == '0'), 'Orbital Period(days)'] = 410.988760
df.loc[(df['Orbital Period(days)'].isna()) & (df['Orbital Period'] == '1'), 'Orbital Period(days)'] = 788.435423
df.loc[(df['Orbital Period(days)'].isna()) & (df['Orbital Period'] == '2'), 'Orbital Period(days)'] = 1213.192540

df['Orbital Velocity(km/s)'] = (2*np.pi*df['Semi Major Axis']*149597871)/(df['Orbital Period(days)']*24*3600)

# %% [markdown]
# ### Escape velocity and Specific orbital energy
# $$\text{Escape Velocity (km/s)} = \text{Orbital Velocity (km/s)} \times \sqrt{2}$$
# $$\text{Specific Orbital Energy} = -\frac{G \cdot M_{sun}}{2 \cdot a}$$
# $$\text{Specific Angular Momentum } = G \cdot M_{sun} \cdot a \cdot (1 - e^2)$$

# %%
df['Escape Velocity(km/s)'] = df['Orbital Velocity(km/s)']*(2**0.5)
df['Specific Orbital Energy (J/kg)'] = -G*M_sun/(2*df['Semi Major Axis']*149597870700)
df['Specific Angular Momentum(kgm/s)'] = G*M_sun*df['Semi Major Axis']*149597870700*(1-df['Eccentricity']**2)

# %% [markdown]
# ### Aphelion and Periheion Velocity
# $$\text{Perihelion Velocity} = \sqrt{\frac{G \cdot M_{sun} \cdot (1 + e)}{(1 - e) \cdot a}}$$
# $$\text{Aphelion Velocity} = \sqrt{\frac{G \cdot M_{sun} \cdot (1 - e)}{(1 + e) \cdot a}}$$

# %%
df['Perihelion Velocity (km/s)'] = (G*M_sun*(1+df['Eccentricity'])/((1-df['Eccentricity'])*df['Semi Major Axis']*149597870700))**0.5/(1000)
df['Aphelion Velocity (km/s)'] = (G*M_sun*(1-df['Eccentricity'])/((1+df['Eccentricity'])*df['Semi Major Axis']*149597870700))**0.5/(1000)

# %% [markdown]
# ### Synodic Period and Mean Motion
# $$\text{Synodic Period (Days)} = \left| \frac{\text{Orbital Period(days)} \cdot 365.25}{\text{Orbital Period(days)} - 365.25} \right|$$
# $$\text{Mean Motion} = \frac{2\pi}{\text{Orbital Period}}$$
# As the mean motion data is already given and can be calculated, we combine both the datas to fill the null values.

# %%
df['Synodic Period(days)'] = abs(df['Orbital Period(days)']*365.25/(df['Orbital Period(days)']-365.25))
df['Mean Motion(rads/days)'] = 2*np.pi/df['Orbital Period(days)']
df['Mean Motion(rads/days)']=df['Mean Motion(rads/days)'].fillna(df['Mean Motion'])
df = df.drop('Mean Motion',axis =1)

# %%
# for column in df.drop(columns=['Name','Epoch Date Close Approach','Epoch Osculation','approach_year','approach_month','approach_day','Orbital Period','Orbit Uncertainity','Hazardous']).columns:
#     plt.figure()  # Create a new figure for each histogram
#     df[column].plot(kind='box')
#     plt.title(f'Box Plot of {column}')
#     plt.xlabel('Value')
#     plt.ylabel('Frequency')
#     plt.show()

# %% [markdown]
# ### Mean Longitude and Precission Rate
#  Precession Rate isthe rate at which the asteroid's orbital elements like the argument of perihelion or the ascending node precess over time. This could influence close approaches.
#
#  Mean Longitude is a measure that can help describe the position of the asteroid in its orbit at a specific time, useful for tracking long-term movements.
# $$\text{Mean Longitude} = \text{Longitude of Ascending Node} + \text{Argument of Perihelion} + \text{Mean Anomaly}$$
# $$\text{Precession Rate} = \frac{3 \text{Mean Motion}{R_{sun}^2}} {a^2  (1 - e^2)}$$

# %%
df[['Mean Anomaly','Asc Node Longitude','Perihelion Arg']]*=(np.pi/180) #Convert it into radians for future use
df['Mean Longitude']=df['Asc Node Longitude']+ df['Perihelion Arg']+ df['Mean Anomaly']
df['Precession Rate'] = (3*df['Mean Motion(rads/days)']/(24*3600)*6.957e8**2)/((df['Semi Major Axis']*149597870700)**2 * (1-df['Eccentricity']**2))

# %% [markdown]
# ### Eccentric Anomaly, True Anomaly, Heliocentric Distance
# Eccentric anomaly is an angular parameter that defines the position of an object moving along an elliptical Kepler orbit, as seen from the center of the ellipse.
#
# True anomaly is a concept in astronomy and physics that measures the angle between an orbiting object's current position and its closest approach to the orbit's focus.
#
# Eccentric anomaly, True anamoly and Mean anamoly are three angular parameters, or anomalies, that define an object's position along an orbit.
# Eccentric anamoly(E) is calculated by solving the Kepler's Equation:
# $$\text{Mean Anomaly} = E - e \cdot \sin(E)$$
# We then calculate True Anamoly by the relation :
# $$\text{True Anomaly} = 2 \arctan \left( \sqrt{\frac{1 + e}{1 - e}} \cdot \tan\left(\frac{E}{2}\right) \right)$$
# By using True Anomaly we calculate the Heliocentric Distance:
# $$\text{Heliocentric Distance} = \frac{a \cdot \left(1 - e^2\right)}{1 + e \cdot \cos(\text{True Anomaly})}$$

# %%
from scipy.optimize import fsolve
def kepler_equation(E, M, e):
    return E - e * np.sin(E) - M
# Function to solve Kepler's equation for eccentric anomaly
def eccentric_anomaly_from_mean_anomaly(M, e):
    E_initial_guess = M  # Use the mean anomaly as an initial guess
    E_solution = fsolve(kepler_equation, E_initial_guess, args=(M, e))
    return E_solution[0]
# Apply the function to the DataFrame using apply
df['Eccentric Anomaly'] = df.apply(lambda row: eccentric_anomaly_from_mean_anomaly(row['Mean Anomaly'], row['Eccentricity']), axis=1)
df['True Anomaly'] = 2*np.arctan(np.sqrt((1 + df['Eccentricity']) / (1 - df['Eccentricity']))*np.tan(df['Eccentric Anomaly']/2))
df['Heliocentric Distance'] = (df['Semi Major Axis'] * (1-df['Eccentricity']**2))/(1+df['Eccentricity']*np.cos(df['True Anomaly']))
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_25968\3214666588.py:7: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   E_solution = fsolve(kepler_equation, E_initial_guess, args=(M, e))

# %%
#Statistics and visualization
df.drop(columns=['Name','Orbital Period','Orbit Uncertainity','Hazardous','Approach Date','Time Until Approach(days)']).describe()
# Out:
#        Relative Velocity km per hr  Miss Dist.(kilometers)  \
# count                  4444.000000            4.519000e+03
# mean                  50321.708436            3.848303e+07
# std                   26199.523498            2.184602e+07
# min                    1207.814804            2.660989e+04
# 25%                   29675.356665            2.002960e+07
# 50%                   46981.986309            3.968541e+07
# 75%                   64544.842167            5.763870e+07
# max                  160681.487900            7.478160e+07
#
#        Jupiter Tisserand Invariant  Semi Major Axis  Asc Node Longitude  \
# count                  2801.000000      4373.000000         3437.000000
# mean                      5.127044         1.351050            3.005178
# std                       1.196647         0.442802            1.798926
# min                       2.367000         0.615920            0.000034
# 25%                       4.180000         1.006096            1.453657
# 50%                       5.104000         1.228501            3.032557
# 75%                       6.043000         1.601858            4.426962
# max                       9.025000         2.568553            6.281543
#
#        Perihelion Arg  Aphelion Dist  Perihelion Time  Mean Anomaly  \
# count     3399.000000    3718.000000     2.970000e+03   3615.000000
# mean         3.232291       1.897422     2.457741e+06      3.189220
# std          1.804583       0.833539     9.155433e+02      1.880963
# min          0.000121       0.803765     2.450100e+06      0.000056
# 25%          1.680260       1.260397     2.457826e+06      1.519367
# 50%          3.359215       1.589961     2.457976e+06      3.299564
# 75%          4.766069       2.330897     2.458109e+06      4.854427
# max          6.283065       4.662158     2.458706e+06      6.281754
#
#        Miss Distance vs Semi Major Axis(AU)  Eccentricity  \
# count                           4359.000000   3588.000000
# mean                               0.213384      0.369164
# std                                0.141191      0.188075
# min                                0.000089     -0.036007
# 25%                                0.096115      0.223704
# 50%                                0.201927      0.354383
# 75%                                0.310864      0.497912
# max                                0.771194      0.999448
#
#        Orbital Period(days)  Orbital Velocity(km/s)  Escape Velocity(km/s)  \
# count           4373.000000             4373.000000            4373.000000
# mean             595.857682               26.582658              37.593555
# std              300.140765                4.006629               5.666229
# min              176.530968               18.587169              26.286227
# 25%              368.547291               23.536701              33.285922
# 50%              497.275867               26.876317              38.008852
# 75%              740.405842               29.698725              42.000340
# max             1503.373384               37.957294              53.679720
#
#        Specific Orbital Energy (J/kg)  Specific Angular Momentum(kgm/s)  \
# count                    4.373000e+03                      3.588000e+03
# mean                    -3.613436e+08                      2.145988e+31
# std                      1.060515e+08                      5.926736e+30
# min                     -7.203781e+08                      4.682230e+28
# 25%                     -4.410071e+08                      1.755718e+31
# 50%                     -3.611682e+08                      2.105708e+31
# 75%                     -2.769882e+08                      2.513736e+31
# max                     -1.727414e+08                      3.772631e+31
#
#        Perihelion Velocity (km/s)  Aphelion Velocity (km/s)  \
# count                 3588.000000               3588.000000
# mean                    41.289620                 18.414645
# std                     23.645112                  5.638663
# min                     26.053919                  0.338783
# 25%                     33.880849                 13.991954
# 50%                     37.724833                 19.018102
# 75%                     44.328359                 22.859469
# max                   1226.659931                 29.610826
#
#        Synodic Period(days)  Mean Motion(rads/days)  Mean Longitude  \
# count          4.373000e+03             4373.000000     2081.000000
# mean           8.757071e+03                0.013054        9.371885
# std            1.593064e+05                0.005611        3.107125
# min            3.416610e+02                0.004179        0.504888
# 25%            7.026813e+02                0.008486        7.154187
# 50%            1.154191e+03                0.012635        9.489753
# 75%            2.518697e+03                0.017049       11.551987
# max            7.690648e+06                0.035593       17.918284
#
#        Precession Rate  Eccentric Anomaly  True Anomaly  Heliocentric Distance
# count     3.588000e+03        3615.000000   2858.000000            2858.000000
# mean      1.079472e-11           3.175164     -0.158031               1.413706
# std       1.746528e-11           1.712079      2.159700               0.674043
# min       6.592726e-13           0.000096     -3.141184               0.200659
# 25%       3.393173e-12           1.756331     -2.323372               1.018424
# 50%       7.096618e-12           3.270149     -0.419210               1.185036
# 75%       1.395379e-11           4.553251      2.032869               1.580464
# max       8.224091e-10           6.280112      3.140770               4.335063

# %%
#BoxPlot for outlier detection
for column in df.drop(columns=['Name','Approach Date','Orbital Period','Orbit Uncertainity','Hazardous']).columns:
    plt.figure()  # Create a new figure for each boxplot
    df[column].plot(kind='box')
    plt.title(f'Box Plot of {column}')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.show()

# %%
#Pairplot for relationship between features and skewness of individual features
sns.pairplot(df.drop(columns=['Name','Approach Date','Orbital Period','Orbit Uncertainity']),hue='Hazardous')
plt.show()

# %%
df.isnull().sum()
# Out:
# Name                                       0
# Relative Velocity km per hr               89
# Miss Dist.(kilometers)                    14
# Jupiter Tisserand Invariant             1732
# Semi Major Axis                          160
# Asc Node Longitude                      1096
# Perihelion Arg                          1134
# Aphelion Dist                            815
# Perihelion Time                         1563
# Mean Anomaly                             918
# Orbital Period                           530
# Orbit Uncertainity                      1766
# Hazardous                                  0
# Approach Date                              0
# Time Until Approach(days)                  0
# Miss Distance vs Semi Major Axis(AU)     174
# Eccentricity                             945
# Orbital Period(days)                     160
# Orbital Velocity(km/s)                   160
# Escape Velocity(km/s)                    160
# Specific Orbital Energy (J/kg)           160
# Specific Angular Momentum(kgm/s)         945
# Perihelion Velocity (km/s)               945
# Aphelion Velocity (km/s)                 945
# Synodic Period(days)                     160
# Mean Motion(rads/days)                   160
# Mean Longitude                          2452
# Precession Rate                          945
# Eccentric Anomaly                        918
# True Anomaly                            1675
# Heliocentric Distance                   1675
# dtype: int64

# %% [markdown]
# <h2>Classification Bias</h2>
# <p>The abundance of data for 0 valued result results in the model biasness towards 0. This is known as classification bias or class imbalance.
# This can be solved by oversampling the minority class or undersampling the majority class, or by assigning lower weights to majority class in your model.</p>

# %%
df['Hazardous'].value_counts()
# Out:
# Hazardous
# 0    3797
# 1     736
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4533 entries, 0 to 4533
# Data columns (total 31 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Name                                  4533 non-null   int64
#  1   Relative Velocity km per hr           4444 non-null   float64
#  2   Miss Dist.(kilometers)                4519 non-null   float64
#  3   Jupiter Tisserand Invariant           2801 non-null   float64
#  4   Semi Major Axis                       4373 non-null   float64
#  5   Asc Node Longitude                    3437 non-null   float64
#  6   Perihelion Arg                        3399 non-null   float64
#  7   Aphelion Dist                         3718 non-null   float64
#  8   Perihelion Time                       2970 non-null   float64
#  9   Mean Anomaly                          3615 non-null   float64
#  10  Orbital Period                        4003 non-null   float64
#  11  Orbit Uncertainity                    2767 non-null   float64
#  12  Hazardous                             4533 non-null   int64
#  13  Approach Date                         4533 non-null   datetime64[ns]
#  14  Time Until Approach(days)             4533 non-null   int64
#  15  Miss Distance vs Semi Major Axis(AU)  4359 non-null   float64
#  16  Eccentricity                          3588 non-null   float64
#  17  Orbital Period(days)                  4373 non-null   float64
#  18  Orbital Velocity(km/s)                4373 non-null   float64
#  19  Escape Velocity(km/s)                 4373 non-null   float64
#  20  Specific Orbital Energy (J/kg)        4373 non-null   float64
#  21  Specific Angular Momentum(kgm/s)      3588 non-null   float64
#  22  Perihelion Velocity (km/s)            3588 non-null   float64
#  23  Aphelion Velocity (km/s)              3588 non-null   float64
#  24  Synodic Period(days)                  4373 non-null   float64
#  25  Mean Motion(rads/days)                4373 non-null   float64
#  26  Mean Longitude                        2081 non-null   float64
#  27  Precession Rate                       3588 non-null   float64
#  28  Eccentric Anomaly                     3615 non-null   float64
#  29  True Anomaly                          2858 non-null   float64
#  30  Heliocentric Distance                 2858 non-null   float64
# dtypes: datetime64[ns](1), float64(27), int64(3)
# memory usage: 1.1 MB

# %%
df.head()
# Out:
#       Name  Relative Velocity km per hr  Miss Dist.(kilometers)  \
# 0  3703080                  22017.00380            6.275369e+07
# 1  3723955                  65210.34609            5.729815e+07
# 2  2446862                  27326.56018            7.622912e+06
# 3  3092506                  40225.94819            4.268363e+07
# 4  3514799                  35426.99179            6.101082e+07
#
#    Jupiter Tisserand Invariant  Semi Major Axis  Asc Node Longitude  \
# 0                          NaN         1.407011            5.486860
# 1                          NaN         1.107776            2.386166
# 2                        4.557         1.458824            4.528710
# 3                        5.093         1.276262            0.997862
# 4                        5.154         1.225615            1.477060
#
#    Perihelion Arg  Aphelion Dist  Perihelion Time  Mean Anomaly  \
# 0        0.999331       2.005764              NaN      4.622287
# 1             NaN       1.497352      2457794.969      3.032354
# 2        4.335660       1.966857      2458120.468           NaN
# 3             NaN       1.527904      2457902.337      1.199757
# 4        2.762221            NaN      2457814.455           NaN
#
#    Orbital Period  Orbit Uncertainity  Hazardous       Approach Date  \
# 0             0.0                 1.0          1 1995-01-01 07:56:40
# 1             0.0                 NaN          0 1995-01-04 19:58:20
# 2             1.0                 NaN          1 1995-01-08 08:00:00
# 3             0.0                 1.0          0 1995-01-15 08:03:20
# 4             NaN                 0.0          1 1995-01-15 08:03:20
#
#    Time Until Approach(days)  Miss Distance vs Semi Major Axis(AU)  \
# 0                      10884                              0.298137
# 1                      10880                              0.345751
# 2                      10877                              0.034930
# 3                      10870                              0.223561
# 4                      10870                              0.332757
#
#    Eccentricity  Orbital Period(days)  Orbital Velocity(km/s)  \
# 0      0.425549            609.509347               25.113587
# 1      0.351674            425.806112               28.302942
# 2      0.348248            643.484747               24.663581
# 3      0.197172            526.554721               26.368639
# 4           NaN            495.524295               26.907947
#
#    Escape Velocity(km/s)  Specific Orbital Energy (J/kg)  \
# 0              35.515976                   -3.153461e+08
# 1              40.026404                   -4.005283e+08
# 2              34.879570                   -3.041461e+08
# 3              37.290886                   -3.476525e+08
# 4              38.053583                   -3.620188e+08
#
#    Specific Angular Momentum(kgm/s)  Perihelion Velocity (km/s)  \
# 0                      2.288224e+31                   39.561557
# 1                      1.927894e+31                   40.866834
# 2                      2.545780e+31                   35.473167
# 3                      2.436042e+31                   32.199906
# 4                               NaN                         NaN
#
#    Aphelion Velocity (km/s)  Synodic Period(days)  Mean Motion(rads/days)  \
# 0                 15.942049            911.421781                0.010309
# 1                 19.601629           2568.290408                0.014756
# 2                 17.147953            844.728441                0.009764
# 3                 21.593389           1192.303054                0.011933
# 4                       NaN           1389.301312                0.012680
#
#    Mean Longitude  Precession Rate  Eccentric Anomaly  True Anomaly  \
# 0       11.108478     4.774962e-12           4.242801     -2.398356
# 1             NaN     1.030385e-11           3.060753      3.085590
# 2             NaN     3.920889e-12                NaN           NaN
# 3             NaN     5.723723e-12           1.393850      1.592706
# 4             NaN              NaN                NaN           NaN
#
#    Heliocentric Distance
# 0               1.677958
# 1               1.496080
# 2                    NaN
# 3               1.231966
# 4                    NaN

# %% [markdown]
# ### Imputation using KNN Imputer
# Finally we impute the remaining missing values using the Robust KNN Imputer

# %%
from sklearn.impute import KNNImputer

# %%
df['Approach Date'] = pd.to_numeric(df['Approach Date'])

# %%
imp_tr = df[df.notnull().all(axis=1)]
imp_te = df[df.notnull().all(axis=1).apply(lambda x: x != True)]

# %%
itr = KNNImputer(n_neighbors=20)

# %%
itr.fit(imp_tr)
# Out:
# KNNImputer(n_neighbors=20)

# %%
df2 = itr.transform(imp_te)

# %%
df3 = pd.DataFrame(df2, columns = imp_te.columns, index = imp_te.index)

# %%
df4 = pd.concat([imp_tr,df3],axis=0)

# %%
df4
# Out:
#            Name  Relative Velocity km per hr  Miss Dist.(kilometers)  \
# 27    2162173.0                 48873.911705            5.247069e+07
# 55    3648769.0                 39036.726310            4.606344e+07
# 73    2154244.0                 58051.773850            4.502404e+07
# 88    3414393.0                 66663.091740            4.803740e+07
# 111   3761271.0                 56981.949240            4.997966e+07
# ...         ...                          ...                     ...
# 4529  3759007.0                 79755.354270            6.187511e+06
# 4530  3759295.0                 11610.539580            9.677324e+05
# 4531  3759714.0                 25889.910630            9.126775e+06
# 4532  3759720.0                 40866.871917            3.900908e+07
# 4533  3772978.0                129408.666300            6.916986e+07
#
#       Jupiter Tisserand Invariant  Semi Major Axis  Asc Node Longitude  \
# 27                         5.3080         1.189561            4.391093
# 55                         6.3790         0.935217            3.563951
# 73                         3.3670         2.306719            3.722548
# 88                         4.5740         1.376451            1.852323
# 111                        7.1760         0.804511            3.597627
# ...                           ...              ...                 ...
# 4529                       5.1560         1.161429            2.865539
# 4530                       5.0549         1.075241            6.025317
# 4531                       4.4100         1.528234            0.646234
# 4532                       4.4770         1.451865            2.858900
# 4533                       4.1080         1.474045            3.274974
#
#       Perihelion Arg  Aphelion Dist  Perihelion Time  Mean Anomaly  \
# 27          3.690442       1.415915     2.457798e+06      2.688186
# 55          0.412814       1.166566     2.458104e+06      4.321508
# 73          1.711113       3.571727     2.457601e+06      1.960230
# 88          4.259708       1.717393     2.457659e+06      5.661689
# 111         5.723738       1.096019     2.458033e+06      5.514622
# ...              ...            ...              ...           ...
# 4529        4.824015       1.581299     2.457692e+06      3.009287
# 4530        0.734977       1.775846     2.458088e+06      3.353129
# 4531        3.428660       2.090708     2.457491e+06      3.551765
# 4532        3.147633       1.787733     2.458288e+06      3.531290
# 4533        3.882253       1.775846     2.458319e+06      3.353129
#
#       Orbital Period  Orbit Uncertainity  Hazardous  Approach Date  \
# 27               0.0                0.00        1.0   7.944483e+17
# 55               0.0                0.00        0.0   7.999160e+17
# 73               2.0                0.00        0.0   8.032000e+17
# 88               0.0                0.00        0.0   8.057920e+17
# 111              0.0                1.00        0.0   8.098095e+17
# ...              ...                 ...        ...            ...
# 4529             0.0                0.60        0.0   1.473320e+18
# 4530             0.4                1.00        0.0   1.473320e+18
# 4531             1.0                0.45        0.0   1.473320e+18
# 4532             1.0                0.75        0.0   1.473320e+18
# 4533             0.4                1.00        0.0   1.473320e+18
#
#       Time Until Approach(days)  Miss Distance vs Semi Major Axis(AU)  \
# 27                      10820.0                              0.294853
# 55                      10757.0                              0.329244
# 73                      10719.0                              0.130474
# 88                      10689.0                              0.233289
# 111                     10643.0                              0.415275
# ...                         ...                                   ...
# 4529                     2963.0                              0.035612
# 4530                     2963.0                              0.006016
# 4531                     2963.0                              0.039921
# 4532                     2963.0                              0.179603
# 4533                     2963.0                              0.313676
#
#       Eccentricity  Orbital Period(days)  Orbital Velocity(km/s)  \
# 27        0.190284            473.820476               27.312677
# 55        0.247375            330.295445               30.803591
# 73        0.548402           1279.457595               19.613732
# 88        0.247697            589.759804               25.390845
# 111       0.362341            263.531241               33.211731
# ...            ...                   ...                     ...
# 4529      0.361512            457.112158               27.641480
# 4530      0.319371            407.185767               28.727953
# 4531      0.368055            689.951903               24.096979
# 4532      0.231336            638.886018               24.722616
# 4533      0.319371            653.582119               24.535909
#
#       Escape Velocity(km/s)  Specific Orbital Energy (J/kg)  \
# 27                38.625958                   -3.729912e+08
# 55                43.562856                   -4.744306e+08
# 73                27.738006                   -1.923492e+08
# 88                35.908077                   -3.223475e+08
# 111               46.968480                   -5.515095e+08
# ...                     ...                             ...
# 4529              39.090955                   -3.820257e+08
# 4530              40.627461                   -4.126476e+08
# 4531              34.078275                   -2.903322e+08
# 4532              34.963058                   -3.056039e+08
# 4533              34.699016                   -3.010054e+08
#
#       Specific Angular Momentum(kgm/s)  Perihelion Velocity (km/s)  \
# 27                        2.276857e+31                   33.114890
# 55                        1.743629e+31                   39.656139
# 73                        3.203291e+31                   36.318343
# 88                        2.565835e+31                   32.699052
# 111                       1.387945e+31                   48.544532
# ...                                ...                         ...
# 4529                      2.005084e+31                   40.364146
# 4530                      2.262270e+31                   37.308217
# 4531                      2.623848e+31                   35.454764
# 4532                      2.729012e+31                   31.290624
# 4533                      2.262270e+31                   37.308217
#
#       Aphelion Velocity (km/s)  Synodic Period(days)  Mean Motion(rads/days)  \
# 27                   22.527096           1594.014642                0.013261
# 55                   23.927221           3451.350218                0.019023
# 73                   10.592402            511.176990                0.004911
# 88                   19.716015            959.467090                0.010654
# 111                  22.721798            946.283518                0.023842
# ...                        ...                   ...                     ...
# 4529                 18.928962           1817.508099                0.013745
# 4530                 19.300890           3546.485786                0.015431
# 4531                 16.377613            776.111658                0.009107
# 4532                 19.533255            852.786558                0.009835
# 4533                 19.300890            827.937137                0.009613
#
#       Mean Longitude  Precession Rate  Eccentric Anomaly  True Anomaly  \
# 27         10.769721     7.301471e-12           2.759191      2.824965
# 55          8.298272     1.739712e-11           4.116735     -2.360150
# 73          7.393892     9.911278e-13           2.350291      2.697887
# 88         11.773720     4.498646e-12           5.484173     -0.996042
# 111        14.835987     3.184271e-11           5.193396     -1.449964
# ...              ...              ...                ...           ...
# 4529       10.191554     8.802350e-12           3.022432     -0.100918
# 4530        8.358325     8.014392e-12           3.321558     -0.476213
# 4531        9.639509     3.386874e-12           3.442632     -2.936156
# 4532       10.649347     3.701617e-12           3.595058     -0.105790
# 4533        8.358325     8.014392e-12           3.321558     -0.476213
#
#       Heliocentric Distance
# 27                 1.399566
# 55                 1.065015
# 73                 3.195919
# 88                 1.138673
# 111                0.669639
# ...                     ...
# 4529               1.223533
# 4530               1.346064
# 4531               2.065413
# 4532               1.530552
# 4533               1.346064
#
# [4533 rows x 31 columns]

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Data Splitting

# %%
from sklearn.model_selection import train_test_split

# %%
X = df4.drop('Hazardous',axis=1)
y = df4['Hazardous']

# Splitting Data as 72% train 18% val and 10% test
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.1, random_state=101) 
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2, random_state=101)

# %% [markdown]
# ### Model Selection
# We used the lazypredict library to analyse the base model performance for numerous Classifiers and select the most robust and efficient model.

# %%
from lazypredict.Supervised import LazyClassifier

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_val, y_train, y_val)

print(models)
# Out:
# 100%|██████████| 31/31 [00:05<00:00,  5.26it/s]
# [LightGBM] [Info] Number of positive: 540, number of negative: 2723
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000814 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7189
# [LightGBM] [Info] Number of data points in the train set: 3263, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.165492 -> initscore=-1.617920
# [LightGBM] [Info] Start training from score -1.617920
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.71               0.67     0.67      0.74
# GaussianNB                         0.73               0.64     0.64      0.76
# XGBClassifier                      0.85               0.62     0.62      0.83
# LGBMClassifier                     0.86               0.62     0.62      0.83
# ExtraTreeClassifier                0.77               0.62     0.62      0.78
# DecisionTreeClassifier             0.79               0.61     0.61      0.79
# LabelPropagation                   0.79               0.60     0.60      0.79
# BaggingClassifier                  0.84               0.60     0.60      0.82
# LabelSpreading                     0.79               0.59     0.59      0.79
# BernoulliNB                        0.80               0.59     0.59      0.80
# AdaBoostClassifier                 0.83               0.59     0.59      0.81
# RandomForestClassifier             0.85               0.58     0.58      0.82
# ExtraTreesClassifier               0.86               0.57     0.57      0.81
# QuadraticDiscriminantAnalysis      0.68               0.57     0.57      0.71
# KNeighborsClassifier               0.84               0.57     0.57      0.81
# Perceptron                         0.78               0.55     0.55      0.77
# LinearDiscriminantAnalysis         0.82               0.54     0.54      0.79
# LogisticRegression                 0.83               0.52     0.52      0.78
# PassiveAggressiveClassifier        0.77               0.52     0.52      0.76
# CalibratedClassifierCV             0.83               0.52     0.52      0.78
# LinearSVC                          0.84               0.52     0.52      0.78
# RidgeClassifier                    0.84               0.52     0.52      0.78
# RidgeClassifierCV                  0.84               0.52     0.52      0.78
# SGDClassifier                      0.84               0.51     0.51      0.78
# SVC                                0.84               0.51     0.51      0.78
# DummyClassifier                    0.84               0.50     0.50      0.77
#
#                                Time Taken
# Model
# NearestCentroid                      0.02
# GaussianNB                           0.01
# XGBClassifier                        0.51
# LGBMClassifier                       0.12
# ExtraTreeClassifier                  0.02
# DecisionTreeClassifier               0.12
# LabelPropagation                     0.54
# BaggingClassifier                    0.70
# LabelSpreading                       0.62
# BernoulliNB                          0.02
# AdaBoostClassifier                   0.58
# RandomForestClassifier               1.28
# ExtraTreesClassifier                 0.35
# QuadraticDiscriminantAnalysis        0.07
# KNeighborsClassifier                 0.20
# Perceptron                           0.02
# LinearDiscriminantAnalysis           0.05
# LogisticRegression                   0.08
# PassiveAggressiveClassifier          0.02
# CalibratedClassifierCV               0.10
# LinearSVC                            0.03
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.12
# SGDClassifier                        0.02
# SVC                                  0.25
# DummyClassifier                      0.01

# %% [markdown]
# #### *The analysis shows that the best model in our case, with a high ROC and F1 score along with the highest Accuracy, is the LightBGM Classifier Model*

# %% [markdown]
# ### Implementing K-Fold Cross Validation
# * We now implement K-Fold Cross Validation with LightGBM as our model
# * The loss calculated here is the logloss

# %%
import lightgbm as lgb

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import log_loss, accuracy_score

k_values = range(2, 11)
results = {k: {"train_loss": [], "val_loss": [], "train_accuracy": [], "val_accuracy": []} for k in k_values}

for k in k_values:
    kf = KFold(n_splits=k)
    for train_index, val_index in kf.split(X_train_val):
        # Splitting the data
        X_train, X_val = X_train_val.iloc[train_index], X_train_val.iloc[val_index]
        y_train, y_val = y_train_val.iloc[train_index], y_train_val.iloc[val_index]
        
        # Defining the LGBMClassifier
        model = lgb.LGBMClassifier()
        
        # Training the model
        model.fit(X_train, y_train)
        
        # Predictions and Metrics for Training Set
        y_train_pred = model.predict(X_train)
        train_loss = log_loss(y_train, model.predict_proba(X_train))
        train_accuracy = accuracy_score(y_train, y_train_pred)
        
        # Predictions and Metrics for Validation Set
        y_val_pred = model.predict(X_val)
        val_loss = log_loss(y_val, model.predict_proba(X_val))
        val_accuracy = accuracy_score(y_val, y_val_pred)
        
        # Recording Metrics
        results[k]["train_loss"].append(train_loss)
        results[k]["val_loss"].append(val_loss)
        results[k]["train_accuracy"].append(train_accuracy)
        results[k]["val_accuracy"].append(val_accuracy)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 347, number of negative: 1692
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000694 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7181
# [LightGBM] [Info] Number of data points in the train set: 2039, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.170181 -> initscore=-1.584342
# [LightGBM] [Info] Start training from score -1.584342
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 322, number of negative: 1718
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000654 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7182
# [LightGBM] [Info] Number of data points in the train set: 2040, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.157843 -> initscore=-1.674365
# [LightGBM] [Info] Start training from score -1.674365
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 464, number of negative: 2255
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000719 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7186
# [LightGBM] [Info] Number of data points in the train set: 2719, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.170651 -> initscore=-1.581021
# [LightGBM] [Info] Start training from score -1.581021
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 437, number of negative: 2282
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000762 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7185
# [LightGBM] [Info] Number of data points in the train set: 2719, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.160721 -> initscore=-1.652874
# [LightGBM] [Info] Start training from score -1.652874
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 437, number of negative: 2283
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000683 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7184
# [LightGBM] [Info] Number of data points in the train set: 2720, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.160662 -> initscore=-1.653312
# [LightGBM] [Info] Start training from score -1.653312
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 514, number of negative: 2545
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000727 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7185
# [LightGBM] [Info] Number of data points in the train set: 3059, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.168029 -> initscore=-1.599663
# [LightGBM] [Info] Start training from score -1.599663
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 502, number of negative: 2557
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000800 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7183
# [LightGBM] [Info] Number of data points in the train set: 3059, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.164106 -> initscore=-1.627990
# [LightGBM] [Info] Start training from score -1.627990
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 484, number of negative: 2575
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000746 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7185
# [LightGBM] [Info] Number of data points in the train set: 3059, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.158222 -> initscore=-1.671520
# [LightGBM] [Info] Start training from score -1.671520
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 507, number of negative: 2553
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000767 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3060, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.165686 -> initscore=-1.616513
# [LightGBM] [Info] Start training from score -1.616513
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 545, number of negative: 2718
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000698 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7186
# [LightGBM] [Info] Number of data points in the train set: 3263, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.167024 -> initscore=-1.606866
# [LightGBM] [Info] Start training from score -1.606866
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 545, number of negative: 2718
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000815 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7186
# [LightGBM] [Info] Number of data points in the train set: 3263, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.167024 -> initscore=-1.606866
# [LightGBM] [Info] Start training from score -1.606866
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 523, number of negative: 2740
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000755 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7185
# [LightGBM] [Info] Number of data points in the train set: 3263, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.160282 -> initscore=-1.656132
# [LightGBM] [Info] Start training from score -1.656132
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 531, number of negative: 2732
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000751 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7186
# [LightGBM] [Info] Number of data points in the train set: 3263, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.162734 -> initscore=-1.638027
# [LightGBM] [Info] Start training from score -1.638027
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 532, number of negative: 2732
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000718 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3264, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.162990 -> initscore=-1.636146
# [LightGBM] [Info] Start training from score -1.636146
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 567, number of negative: 2832
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000699 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3399, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.166814 -> initscore=-1.608379
# [LightGBM] [Info] Start training from score -1.608379
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 566, number of negative: 2833
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000775 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7186
# [LightGBM] [Info] Number of data points in the train set: 3399, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.166520 -> initscore=-1.610497
# [LightGBM] [Info] Start training from score -1.610497
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 552, number of negative: 2847
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000731 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7185
# [LightGBM] [Info] Number of data points in the train set: 3399, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.162401 -> initscore=-1.640473
# [LightGBM] [Info] Start training from score -1.640473
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 554, number of negative: 2845
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000810 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7188
# [LightGBM] [Info] Number of data points in the train set: 3399, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.162989 -> initscore=-1.636154
# [LightGBM] [Info] Start training from score -1.636154
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 552, number of negative: 2847
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000669 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3399, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.162401 -> initscore=-1.640473
# [LightGBM] [Info] Start training from score -1.640473
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 554, number of negative: 2846
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000782 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7186
# [LightGBM] [Info] Number of data points in the train set: 3400, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.162941 -> initscore=-1.636505
# [LightGBM] [Info] Start training from score -1.636505
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 581, number of negative: 2915
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000820 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3496, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.166190 -> initscore=-1.612874
# [LightGBM] [Info] Start training from score -1.612874
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 579, number of negative: 2917
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000677 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3496, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.165618 -> initscore=-1.617008
# [LightGBM] [Info] Start training from score -1.617008
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 574, number of negative: 2922
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000739 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7186
# [LightGBM] [Info] Number of data points in the train set: 3496, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.164188 -> initscore=-1.627394
# [LightGBM] [Info] Start training from score -1.627394
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 571, number of negative: 2925
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000719 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3496, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.163330 -> initscore=-1.633661
# [LightGBM] [Info] Start training from score -1.633661
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 566, number of negative: 2930
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000746 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7186
# [LightGBM] [Info] Number of data points in the train set: 3496, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.161899 -> initscore=-1.644164
# [LightGBM] [Info] Start training from score -1.644164
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 573, number of negative: 2924
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000709 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7186
# [LightGBM] [Info] Number of data points in the train set: 3497, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.163855 -> initscore=-1.629822
# [LightGBM] [Info] Start training from score -1.629822
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 570, number of negative: 2927
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000739 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7186
# [LightGBM] [Info] Number of data points in the train set: 3497, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.162997 -> initscore=-1.636097
# [LightGBM] [Info] Start training from score -1.636097
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 591, number of negative: 2978
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000771 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3569, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.165593 -> initscore=-1.617191
# [LightGBM] [Info] Start training from score -1.617191
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 592, number of negative: 2977
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000663 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3569, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.165873 -> initscore=-1.615165
# [LightGBM] [Info] Start training from score -1.615165
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 590, number of negative: 2979
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000740 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3569, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.165312 -> initscore=-1.619220
# [LightGBM] [Info] Start training from score -1.619220
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 581, number of negative: 2988
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000676 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7185
# [LightGBM] [Info] Number of data points in the train set: 3569, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.162791 -> initscore=-1.637609
# [LightGBM] [Info] Start training from score -1.637609
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 578, number of negative: 2991
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000655 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3569, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.161950 -> initscore=-1.643789
# [LightGBM] [Info] Start training from score -1.643789
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 575, number of negative: 2994
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000992 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3569, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.161110 -> initscore=-1.649996
# [LightGBM] [Info] Start training from score -1.649996
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 594, number of negative: 2975
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000746 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7188
# [LightGBM] [Info] Number of data points in the train set: 3569, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.166433 -> initscore=-1.611120
# [LightGBM] [Info] Start training from score -1.611120
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 582, number of negative: 2988
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000756 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3570, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.163025 -> initscore=-1.635889
# [LightGBM] [Info] Start training from score -1.635889
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 604, number of negative: 3021
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000752 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3625, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.166621 -> initscore=-1.609769
# [LightGBM] [Info] Start training from score -1.609769
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 596, number of negative: 3029
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000743 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3625, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.164414 -> initscore=-1.625747
# [LightGBM] [Info] Start training from score -1.625747
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 602, number of negative: 3024
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000824 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3626, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.166023 -> initscore=-1.614078
# [LightGBM] [Info] Start training from score -1.614078
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 592, number of negative: 3034
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000930 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7186
# [LightGBM] [Info] Number of data points in the train set: 3626, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.163265 -> initscore=-1.634131
# [LightGBM] [Info] Start training from score -1.634131
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 588, number of negative: 3038
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000828 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3626, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.162162 -> initscore=-1.642228
# [LightGBM] [Info] Start training from score -1.642228
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 595, number of negative: 3031
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000779 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7188
# [LightGBM] [Info] Number of data points in the train set: 3626, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.164093 -> initscore=-1.628086
# [LightGBM] [Info] Start training from score -1.628086
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 586, number of negative: 3040
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000742 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3626, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.161611 -> initscore=-1.646293
# [LightGBM] [Info] Start training from score -1.646293
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 598, number of negative: 3028
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000757 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7190
# [LightGBM] [Info] Number of data points in the train set: 3626, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.164920 -> initscore=-1.622067
# [LightGBM] [Info] Start training from score -1.622067
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 591, number of negative: 3035
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000763 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7186
# [LightGBM] [Info] Number of data points in the train set: 3626, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.162990 -> initscore=-1.636151
# [LightGBM] [Info] Start training from score -1.636151
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 610, number of negative: 3061
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000764 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7188
# [LightGBM] [Info] Number of data points in the train set: 3671, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.166167 -> initscore=-1.613038
# [LightGBM] [Info] Start training from score -1.613038
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 604, number of negative: 3067
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000774 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3671, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.164533 -> initscore=-1.624881
# [LightGBM] [Info] Start training from score -1.624881
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 607, number of negative: 3064
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000752 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7188
# [LightGBM] [Info] Number of data points in the train set: 3671, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.165350 -> initscore=-1.618948
# [LightGBM] [Info] Start training from score -1.618948
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 607, number of negative: 3064
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000803 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7188
# [LightGBM] [Info] Number of data points in the train set: 3671, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.165350 -> initscore=-1.618948
# [LightGBM] [Info] Start training from score -1.618948
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 595, number of negative: 3076
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000796 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7186
# [LightGBM] [Info] Number of data points in the train set: 3671, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.162081 -> initscore=-1.642824
# [LightGBM] [Info] Start training from score -1.642824
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 597, number of negative: 3074
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000804 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7188
# [LightGBM] [Info] Number of data points in the train set: 3671, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.162626 -> initscore=-1.638818
# [LightGBM] [Info] Start training from score -1.638818
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 602, number of negative: 3069
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000784 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7188
# [LightGBM] [Info] Number of data points in the train set: 3671, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.163988 -> initscore=-1.628850
# [LightGBM] [Info] Start training from score -1.628850
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 598, number of negative: 3073
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000790 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3671, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.162898 -> initscore=-1.636819
# [LightGBM] [Info] Start training from score -1.636819
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 601, number of negative: 3070
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000744 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7187
# [LightGBM] [Info] Number of data points in the train set: 3671, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.163716 -> initscore=-1.630838
# [LightGBM] [Info] Start training from score -1.630838
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 600, number of negative: 3072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000762 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7186
# [LightGBM] [Info] Number of data points in the train set: 3672, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.163399 -> initscore=-1.633154
# [LightGBM] [Info] Start training from score -1.633154

# %%
# Plotting Figures
for metric in ["train_loss", "val_loss", "train_accuracy", "val_accuracy"]:
    plt.figure(figsize=(10, 6))
    for k, metrics in results.items():
        plt.plot(metrics[metric], label=f"K={k}")
    plt.title(f"{metric.replace('_', ' ').title()} vs Epochs")
    plt.xlabel("Epochs")
    plt.ylabel(metric.replace('_', ' ').title())
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# **Consistency and less variation in these plots indicate the robustness of the model.**

# %% [markdown]
# ### Hyper Parameter Tuning Using Optuna

# %%
import sklearn
import optuna

# %%
def objectivelgb(trial):
    dtrain = lgb.Dataset(X_train, label=y_train)

    param = {
        "objective": "binary",
        "metric": "binary_logloss",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
    }

    gbm = lgb.train(param, dtrain)
    preds = gbm.predict(X_val)
    pred_labels = np.rint(preds)
    accuracy = sklearn.metrics.accuracy_score(y_val, pred_labels)
    return accuracy

# %% [markdown]
# We chose the pruning method as Hyperband Pruner as it gradually increases resources for promising trials, discarding the less promising ones early on. It allows exploration of more hyperparameter combinations initially, but then narrows down based on performance. Thus, it is highly computationally efficient when the search space of hyperparameters is large.

# %%
study = optuna.create_study(direction="maximize",pruner=optuna.pruners.HyperbandPruner)
study.optimize(objectivelgb, n_trials=500)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2024-10-19 19:18:07,952] A new study created in memory with name: no-name-19e1e922-9c92-4b33-a2af-aa8dad6bd906
# [I 2024-10-19 19:18:08,103] Trial 0 finished with value: 0.8525798525798526 and parameters: {'lambda_l1': 8.470841320599646e-08, 'lambda_l2': 1.6105404763858, 'num_leaves': 228, 'feature_fraction': 0.619758822227882, 'bagging_fraction': 0.8460028724578889, 'bagging_freq': 6, 'min_child_samples': 80}. Best is trial 0 with value: 0.8525798525798526.
# [I 2024-10-19 19:18:08,393] Trial 1 finished with value: 0.8574938574938575 and parameters: {'lambda_l1': 0.0004652874260041963, 'lambda_l2': 1.775285554250622e-06, 'num_leaves': 74, 'feature_fraction': 0.9561351145414031, 'bagging_fraction': 0.4224636892424011, 'bagging_freq': 6, 'min_child_samples': 15}. Best is trial 1 with value: 0.8574938574938575.
# [I 2024-10-19 19:18:08,532] Trial 2 finished with value: 0.855036855036855 and parameters: {'lambda_l1': 3.4125538910577216e-07, 'lambda_l2': 2.207555836825228e-08, 'num_leaves': 147, 'feature_fraction': 0.8103251683510274, 'bagging_fraction': 0.597895547136607, 'bagging_freq': 5, 'min_child_samples': 56}. Best is trial 1 with value: 0.8574938574938575.
# [I 2024-10-19 19:18:08,637] Trial 3 finished with value: 0.855036855036855 and parameters: {'lambda_l1': 1.3755575662928184e-05, 'lambda_l2': 3.0470423647142417, 'num_leaves': 54, 'feature_fraction': 0.56793126716518, 'bagging_fraction': 0.7207439308835513, 'bagging_freq': 2, 'min_child_samples': 86}. Best is trial 1 with value: 0.8574938574938575.
# [I 2024-10-19 19:18:08,745] Trial 4 finished with value: 0.8402948402948403 and parameters: {'lambda_l1': 0.00023290348815298954, 'lambda_l2': 1.7843564895000543, 'num_leaves': 47, 'feature_fraction': 0.9412739102512705, 'bagging_fraction': 0.5624878602544059, 'bagging_freq': 5, 'min_child_samples': 87}. Best is trial 1 with value: 0.8574938574938575.
# [I 2024-10-19 19:18:08,869] Trial 5 finished with value: 0.8722358722358723 and parameters: {'lambda_l1': 0.00046081128043275996, 'lambda_l2': 5.733660426351046e-07, 'num_leaves': 163, 'feature_fraction': 0.705612872470706, 'bagging_fraction': 0.9162359115761582, 'bagging_freq': 3, 'min_child_samples': 88}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:09,021] Trial 6 finished with value: 0.8574938574938575 and parameters: {'lambda_l1': 0.0017657460348597966, 'lambda_l2': 1.1788738014052031e-08, 'num_leaves': 87, 'feature_fraction': 0.6437522238648519, 'bagging_fraction': 0.8716545172887502, 'bagging_freq': 5, 'min_child_samples': 68}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:09,158] Trial 7 finished with value: 0.855036855036855 and parameters: {'lambda_l1': 0.08967475521433962, 'lambda_l2': 1.995637315596479e-07, 'num_leaves': 36, 'feature_fraction': 0.8101466877790402, 'bagging_fraction': 0.8189692011296084, 'bagging_freq': 2, 'min_child_samples': 86}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:09,589] Trial 8 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 1.7906014536822956e-06, 'lambda_l2': 1.2539768906464252e-07, 'num_leaves': 149, 'feature_fraction': 0.889659649787216, 'bagging_fraction': 0.8528061200429642, 'bagging_freq': 5, 'min_child_samples': 15}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:09,718] Trial 9 finished with value: 0.855036855036855 and parameters: {'lambda_l1': 6.817314345464245e-08, 'lambda_l2': 0.21420116313643475, 'num_leaves': 53, 'feature_fraction': 0.8581747077173725, 'bagging_fraction': 0.7747146139664587, 'bagging_freq': 4, 'min_child_samples': 82}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:09,892] Trial 10 finished with value: 0.8574938574938575 and parameters: {'lambda_l1': 6.317072259777027, 'lambda_l2': 6.978807705142014e-05, 'num_leaves': 210, 'feature_fraction': 0.4399962470647674, 'bagging_fraction': 0.9959739960609665, 'bagging_freq': 1, 'min_child_samples': 35}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:10,301] Trial 11 finished with value: 0.8648648648648649 and parameters: {'lambda_l1': 6.197436322511375e-06, 'lambda_l2': 1.9318425073300672e-05, 'num_leaves': 151, 'feature_fraction': 0.728204779730194, 'bagging_fraction': 0.9702455710704132, 'bagging_freq': 3, 'min_child_samples': 28}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:10,546] Trial 12 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 1.818413689858948e-05, 'lambda_l2': 4.6281400100936275e-05, 'num_leaves': 187, 'feature_fraction': 0.7334303174833418, 'bagging_fraction': 0.9626529423651511, 'bagging_freq': 3, 'min_child_samples': 37}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:10,687] Trial 13 finished with value: 0.8427518427518428 and parameters: {'lambda_l1': 0.008274296210329183, 'lambda_l2': 0.011076186939584001, 'num_leaves': 114, 'feature_fraction': 0.7161746459098136, 'bagging_fraction': 0.9399779601153391, 'bagging_freq': 3, 'min_child_samples': 99}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:10,975] Trial 14 finished with value: 0.8452088452088452 and parameters: {'lambda_l1': 0.07138622333886425, 'lambda_l2': 4.823732832060618e-06, 'num_leaves': 182, 'feature_fraction': 0.5216306646004896, 'bagging_fraction': 0.9057406759009428, 'bagging_freq': 3, 'min_child_samples': 34}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:11,155] Trial 15 finished with value: 0.8476658476658476 and parameters: {'lambda_l1': 3.052891203397298e-05, 'lambda_l2': 0.006539747462314142, 'num_leaves': 247, 'feature_fraction': 0.7680618432106701, 'bagging_fraction': 0.6219733406853394, 'bagging_freq': 1, 'min_child_samples': 53}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:11,240] Trial 16 finished with value: 0.8501228501228502 and parameters: {'lambda_l1': 1.6412124877503036e-06, 'lambda_l2': 0.0009590127702782494, 'num_leaves': 7, 'feature_fraction': 0.6693417280198227, 'bagging_fraction': 0.7463700570989245, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:11,404] Trial 17 finished with value: 0.8427518427518428 and parameters: {'lambda_l1': 1.3550702483004614e-08, 'lambda_l2': 3.2203277078206895e-06, 'num_leaves': 125, 'feature_fraction': 0.569246399084967, 'bagging_fraction': 0.9238376935526764, 'bagging_freq': 4, 'min_child_samples': 65}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:11,589] Trial 18 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 0.00012107218323456405, 'lambda_l2': 2.5922289469549598e-05, 'num_leaves': 168, 'feature_fraction': 0.4151198191014813, 'bagging_fraction': 0.6605453432601236, 'bagging_freq': 2, 'min_child_samples': 45}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:11,977] Trial 19 finished with value: 0.855036855036855 and parameters: {'lambda_l1': 0.006193463813057718, 'lambda_l2': 3.457731642668746e-07, 'num_leaves': 203, 'feature_fraction': 0.761925401112811, 'bagging_fraction': 0.9903240225896233, 'bagging_freq': 3, 'min_child_samples': 24}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:12,104] Trial 20 finished with value: 0.8525798525798526 and parameters: {'lambda_l1': 4.83761111759352, 'lambda_l2': 0.0004568126660353945, 'num_leaves': 93, 'feature_fraction': 0.6852783678915123, 'bagging_fraction': 0.7966262617841623, 'bagging_freq': 4, 'min_child_samples': 72}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:12,334] Trial 21 finished with value: 0.8574938574938575 and parameters: {'lambda_l1': 1.7063186467207532e-05, 'lambda_l2': 3.109053708418568e-05, 'num_leaves': 180, 'feature_fraction': 0.7423465788488581, 'bagging_fraction': 0.9277154480936602, 'bagging_freq': 3, 'min_child_samples': 43}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:12,622] Trial 22 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 2.15343472347989e-06, 'lambda_l2': 0.00013857459835846722, 'num_leaves': 152, 'feature_fraction': 0.8171624924117591, 'bagging_fraction': 0.9670873533294616, 'bagging_freq': 2, 'min_child_samples': 30}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:12,825] Trial 23 finished with value: 0.8525798525798526 and parameters: {'lambda_l1': 5.315551805356304e-05, 'lambda_l2': 1.2054253338471644e-05, 'num_leaves': 196, 'feature_fraction': 0.7092844025033299, 'bagging_fraction': 0.882197659592791, 'bagging_freq': 4, 'min_child_samples': 45}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:13,166] Trial 24 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 5.683245997810637e-06, 'lambda_l2': 6.679338723519846e-07, 'num_leaves': 109, 'feature_fraction': 0.6175620115191122, 'bagging_fraction': 0.9515604538260147, 'bagging_freq': 3, 'min_child_samples': 26}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:13,392] Trial 25 finished with value: 0.855036855036855 and parameters: {'lambda_l1': 6.295703368831186e-06, 'lambda_l2': 8.582123083673774e-07, 'num_leaves': 124, 'feature_fraction': 0.5998079791120846, 'bagging_fraction': 0.5282517804040738, 'bagging_freq': 2, 'min_child_samples': 23}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:13,519] Trial 26 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 0.0007399267698393843, 'lambda_l2': 6.434389859146037e-08, 'num_leaves': 106, 'feature_fraction': 0.499866311514629, 'bagging_fraction': 0.9990614144284803, 'bagging_freq': 3, 'min_child_samples': 100}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:14,051] Trial 27 finished with value: 0.8722358722358723 and parameters: {'lambda_l1': 4.7554119407464406e-07, 'lambda_l2': 7.636816725299377e-07, 'num_leaves': 141, 'feature_fraction': 0.6709322470719933, 'bagging_fraction': 0.8990946590175728, 'bagging_freq': 4, 'min_child_samples': 5}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:14,396] Trial 28 finished with value: 0.855036855036855 and parameters: {'lambda_l1': 6.269248776319559e-07, 'lambda_l2': 7.077371513744611e-07, 'num_leaves': 96, 'feature_fraction': 0.6516986946597227, 'bagging_fraction': 0.8217297141188267, 'bagging_freq': 4, 'min_child_samples': 5}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:14,962] Trial 29 finished with value: 0.8648648648648649 and parameters: {'lambda_l1': 1.0938001655621153e-07, 'lambda_l2': 4.8015175621800266e-08, 'num_leaves': 132, 'feature_fraction': 0.594898017827318, 'bagging_fraction': 0.8902509966500247, 'bagging_freq': 6, 'min_child_samples': 14}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:15,237] Trial 30 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 1.972979039888676e-08, 'lambda_l2': 1.6474245542034493e-06, 'num_leaves': 225, 'feature_fraction': 0.5076964992337871, 'bagging_fraction': 0.851555054909789, 'bagging_freq': 4, 'min_child_samples': 61}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:15,904] Trial 31 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 3.437794503386321e-07, 'lambda_l2': 5.708084350815938e-06, 'num_leaves': 160, 'feature_fraction': 0.615146724069871, 'bagging_fraction': 0.9390524077697824, 'bagging_freq': 3, 'min_child_samples': 23}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:16,723] Trial 32 finished with value: 0.8697788697788698 and parameters: {'lambda_l1': 1.5215376135158337e-07, 'lambda_l2': 5.7566169561014264e-06, 'num_leaves': 164, 'feature_fraction': 0.6220055755805008, 'bagging_fraction': 0.9321463790427269, 'bagging_freq': 4, 'min_child_samples': 12}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:17,176] Trial 33 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 8.510288498268604e-08, 'lambda_l2': 6.059597889673327e-07, 'num_leaves': 134, 'feature_fraction': 0.5488518185079041, 'bagging_fraction': 0.9048669554880626, 'bagging_freq': 4, 'min_child_samples': 11}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:17,646] Trial 34 finished with value: 0.855036855036855 and parameters: {'lambda_l1': 6.826818673776867e-07, 'lambda_l2': 3.787141126444028e-08, 'num_leaves': 171, 'feature_fraction': 0.6359966723379329, 'bagging_fraction': 0.8383654480950071, 'bagging_freq': 5, 'min_child_samples': 11}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:17,919] Trial 35 finished with value: 0.8353808353808354 and parameters: {'lambda_l1': 0.00010545317042090767, 'lambda_l2': 1.605568912733074e-07, 'num_leaves': 139, 'feature_fraction': 0.6861178915512907, 'bagging_fraction': 0.41781071506742146, 'bagging_freq': 6, 'min_child_samples': 15}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:18,126] Trial 36 finished with value: 0.8501228501228502 and parameters: {'lambda_l1': 1.464003444334577e-07, 'lambda_l2': 2.264917965705494e-06, 'num_leaves': 71, 'feature_fraction': 0.6175724367608609, 'bagging_fraction': 0.4644803118270826, 'bagging_freq': 5, 'min_child_samples': 20}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:18,453] Trial 37 finished with value: 0.8402948402948403 and parameters: {'lambda_l1': 0.0003498943953752144, 'lambda_l2': 1.0966563704324356e-08, 'num_leaves': 74, 'feature_fraction': 0.5578700753183836, 'bagging_fraction': 0.6925048700696521, 'bagging_freq': 2, 'min_child_samples': 8}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:18,723] Trial 38 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 3.5708007816904406e-08, 'lambda_l2': 7.996472027263991, 'num_leaves': 109, 'feature_fraction': 0.6600098123555946, 'bagging_fraction': 0.7806902990596127, 'bagging_freq': 5, 'min_child_samples': 16}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:18,887] Trial 39 finished with value: 0.8476658476658476 and parameters: {'lambda_l1': 5.648207564478831e-06, 'lambda_l2': 2.514675618495707e-07, 'num_leaves': 160, 'feature_fraction': 0.47346040035436865, 'bagging_fraction': 0.8731467067450177, 'bagging_freq': 4, 'min_child_samples': 93}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:19,209] Trial 40 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 2.605237756093728e-07, 'lambda_l2': 9.160366917116448e-06, 'num_leaves': 142, 'feature_fraction': 0.8037262197425742, 'bagging_fraction': 0.7463837951968492, 'bagging_freq': 4, 'min_child_samples': 29}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:19,686] Trial 41 finished with value: 0.8722358722358723 and parameters: {'lambda_l1': 6.156515610708912e-07, 'lambda_l2': 6.8437858040313175e-06, 'num_leaves': 163, 'feature_fraction': 0.6137125324761646, 'bagging_fraction': 0.9395123498722584, 'bagging_freq': 3, 'min_child_samples': 19}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:20,491] Trial 42 finished with value: 0.8574938574938575 and parameters: {'lambda_l1': 1.129087436492631e-06, 'lambda_l2': 1.1042560818469398e-06, 'num_leaves': 217, 'feature_fraction': 0.587235264111374, 'bagging_fraction': 0.9511541007875968, 'bagging_freq': 3, 'min_child_samples': 10}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:20,677] Trial 43 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 4.045064925176259e-06, 'lambda_l2': 0.00015604666888554232, 'num_leaves': 171, 'feature_fraction': 0.6343084408406627, 'bagging_fraction': 0.9082753617083497, 'bagging_freq': 2, 'min_child_samples': 75}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:21,171] Trial 44 finished with value: 0.8722358722358723 and parameters: {'lambda_l1': 0.0011593000814181852, 'lambda_l2': 2.6581926076545614e-06, 'num_leaves': 117, 'feature_fraction': 0.685888172037434, 'bagging_fraction': 0.8502243709527598, 'bagging_freq': 3, 'min_child_samples': 19}. Best is trial 5 with value: 0.8722358722358723.
# [I 2024-10-19 19:18:21,669] Trial 45 finished with value: 0.8796068796068796 and parameters: {'lambda_l1': 0.0018008771918280042, 'lambda_l2': 3.969462294235593e-06, 'num_leaves': 195, 'feature_fraction': 0.993074240386605, 'bagging_fraction': 0.8652110625133633, 'bagging_freq': 4, 'min_child_samples': 19}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:22,044] Trial 46 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 0.00227875401256643, 'lambda_l2': 9.094096976820851e-08, 'num_leaves': 192, 'feature_fraction': 0.9590693746126694, 'bagging_fraction': 0.8151700511910407, 'bagging_freq': 3, 'min_child_samples': 19}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:22,288] Trial 47 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 0.01923704369545558, 'lambda_l2': 0.0017585029243419028, 'num_leaves': 253, 'feature_fraction': 0.871632901903233, 'bagging_fraction': 0.8529111058608005, 'bagging_freq': 2, 'min_child_samples': 38}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:22,756] Trial 48 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 0.0015403694515922055, 'lambda_l2': 2.3586479264603613e-06, 'num_leaves': 179, 'feature_fraction': 0.9377069827005011, 'bagging_fraction': 0.8628806051174407, 'bagging_freq': 5, 'min_child_samples': 19}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:23,060] Trial 49 finished with value: 0.8574938574938575 and parameters: {'lambda_l1': 0.041911795943412815, 'lambda_l2': 0.11530110156244508, 'num_leaves': 237, 'feature_fraction': 0.7846484390920072, 'bagging_fraction': 0.8903545898656703, 'bagging_freq': 1, 'min_child_samples': 32}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:23,236] Trial 50 finished with value: 0.8722358722358723 and parameters: {'lambda_l1': 0.20508359499416204, 'lambda_l2': 2.89819952985558e-07, 'num_leaves': 206, 'feature_fraction': 0.99704612885826, 'bagging_fraction': 0.8182914210337502, 'bagging_freq': 3, 'min_child_samples': 79}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:23,419] Trial 51 finished with value: 0.8648648648648649 and parameters: {'lambda_l1': 0.4291631951981332, 'lambda_l2': 1.9218407520702187e-07, 'num_leaves': 205, 'feature_fraction': 0.9778181918872444, 'bagging_fraction': 0.8245089204693057, 'bagging_freq': 3, 'min_child_samples': 82}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:23,575] Trial 52 finished with value: 0.8501228501228502 and parameters: {'lambda_l1': 0.46296665500326617, 'lambda_l2': 3.7053193103188003e-07, 'num_leaves': 153, 'feature_fraction': 0.9989016673460815, 'bagging_fraction': 0.7961378747153504, 'bagging_freq': 3, 'min_child_samples': 95}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:23,750] Trial 53 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 0.0006455775763119302, 'lambda_l2': 1.7126858814826097e-05, 'num_leaves': 213, 'feature_fraction': 0.9264629784647249, 'bagging_fraction': 0.9114266267077554, 'bagging_freq': 3, 'min_child_samples': 87}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:23,917] Trial 54 finished with value: 0.8476658476658476 and parameters: {'lambda_l1': 0.005529958892064517, 'lambda_l2': 6.342658051761613e-05, 'num_leaves': 120, 'feature_fraction': 0.9096063165898952, 'bagging_fraction': 0.7398812660902553, 'bagging_freq': 4, 'min_child_samples': 79}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:24,084] Trial 55 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 0.00018829068178619263, 'lambda_l2': 2.809818191273588e-06, 'num_leaves': 198, 'feature_fraction': 0.9971769973202811, 'bagging_fraction': 0.8747125948153374, 'bagging_freq': 3, 'min_child_samples': 92}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:24,296] Trial 56 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 0.3462168033542581, 'lambda_l2': 3.714935145800282e-07, 'num_leaves': 184, 'feature_fraction': 0.6899227362971497, 'bagging_fraction': 0.968573109589236, 'bagging_freq': 2, 'min_child_samples': 60}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:24,594] Trial 57 finished with value: 0.8525798525798526 and parameters: {'lambda_l1': 4.980402814096828e-05, 'lambda_l2': 2.8393676834435753e-08, 'num_leaves': 224, 'feature_fraction': 0.7489356303608915, 'bagging_fraction': 0.7739441451731883, 'bagging_freq': 4, 'min_child_samples': 40}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:24,798] Trial 58 finished with value: 0.8574938574938575 and parameters: {'lambda_l1': 0.002590688864046674, 'lambda_l2': 1.2181640668360953e-06, 'num_leaves': 239, 'feature_fraction': 0.8312702293678144, 'bagging_fraction': 0.892171201973427, 'bagging_freq': 3, 'min_child_samples': 71}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:25,224] Trial 59 finished with value: 0.8574938574938575 and parameters: {'lambda_l1': 1.3572632702875813, 'lambda_l2': 9.349549956179721e-08, 'num_leaves': 145, 'feature_fraction': 0.7147487247076353, 'bagging_fraction': 0.8387650510262599, 'bagging_freq': 5, 'min_child_samples': 7}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:25,480] Trial 60 finished with value: 0.8501228501228502 and parameters: {'lambda_l1': 0.014022036152138975, 'lambda_l2': 9.025597724866089e-06, 'num_leaves': 176, 'feature_fraction': 0.9043134161481458, 'bagging_fraction': 0.9824640208534651, 'bagging_freq': 4, 'min_child_samples': 48}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:26,031] Trial 61 finished with value: 0.8574938574938575 and parameters: {'lambda_l1': 0.0008396675605533923, 'lambda_l2': 5.158034457644362e-06, 'num_leaves': 163, 'feature_fraction': 0.6788397160075208, 'bagging_fraction': 0.921003317653397, 'bagging_freq': 4, 'min_child_samples': 14}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:26,396] Trial 62 finished with value: 0.8697788697788698 and parameters: {'lambda_l1': 0.15324265440819002, 'lambda_l2': 4.861818264506668e-06, 'num_leaves': 190, 'feature_fraction': 0.6619594976482073, 'bagging_fraction': 0.9388480850327502, 'bagging_freq': 4, 'min_child_samples': 21}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:26,790] Trial 63 finished with value: 0.8746928746928747 and parameters: {'lambda_l1': 0.003947258710722486, 'lambda_l2': 3.078947125185759e-05, 'num_leaves': 158, 'feature_fraction': 0.9651261163170943, 'bagging_fraction': 0.9294902596752919, 'bagging_freq': 3, 'min_child_samples': 17}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:27,166] Trial 64 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 0.005171734037962763, 'lambda_l2': 2.595800757562904e-05, 'num_leaves': 153, 'feature_fraction': 0.9718111131320177, 'bagging_fraction': 0.8579778427272284, 'bagging_freq': 3, 'min_child_samples': 18}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:27,479] Trial 65 finished with value: 0.8697788697788698 and parameters: {'lambda_l1': 0.0014514540453993386, 'lambda_l2': 0.0001756726989878345, 'num_leaves': 127, 'feature_fraction': 0.9545015783640208, 'bagging_fraction': 0.9516054254370788, 'bagging_freq': 2, 'min_child_samples': 25}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:27,625] Trial 66 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 0.03151894261654361, 'lambda_l2': 8.224404224089174e-05, 'num_leaves': 117, 'feature_fraction': 0.8452651510145902, 'bagging_fraction': 0.9015187037907548, 'bagging_freq': 3, 'min_child_samples': 84}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:27,897] Trial 67 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 0.0002384255972368077, 'lambda_l2': 1.5802351070732905e-06, 'num_leaves': 136, 'feature_fraction': 0.9787821909437627, 'bagging_fraction': 0.8051265853581174, 'bagging_freq': 3, 'min_child_samples': 27}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:27,968] Trial 68 finished with value: 0.8353808353808354 and parameters: {'lambda_l1': 8.596007801956157e-05, 'lambda_l2': 1.645057024463536e-05, 'num_leaves': 2, 'feature_fraction': 0.8840721932838672, 'bagging_fraction': 0.8378939014827468, 'bagging_freq': 7, 'min_child_samples': 89}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:28,140] Trial 69 finished with value: 0.8525798525798526 and parameters: {'lambda_l1': 0.003532963712901513, 'lambda_l2': 4.098533477391105e-05, 'num_leaves': 201, 'feature_fraction': 0.9330347898504829, 'bagging_fraction': 0.9778158055284382, 'bagging_freq': 2, 'min_child_samples': 77}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:28,684] Trial 70 finished with value: 0.8697788697788698 and parameters: {'lambda_l1': 0.011976813576672503, 'lambda_l2': 8.532682607170611e-07, 'num_leaves': 158, 'feature_fraction': 0.7303720785512394, 'bagging_fraction': 0.9223744809794632, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 45 with value: 0.8796068796068796.
# [I 2024-10-19 19:18:29,170] Trial 71 finished with value: 0.8820638820638821 and parameters: {'lambda_l1': 0.00040359937187829377, 'lambda_l2': 8.946631570221641e-06, 'num_leaves': 165, 'feature_fraction': 0.7028277173585991, 'bagging_fraction': 0.9320184915751039, 'bagging_freq': 4, 'min_child_samples': 11}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:29,553] Trial 72 finished with value: 0.8697788697788698 and parameters: {'lambda_l1': 0.00045094350166622, 'lambda_l2': 8.521669989480442e-06, 'num_leaves': 173, 'feature_fraction': 0.7133722240994481, 'bagging_fraction': 0.8815029827726448, 'bagging_freq': 3, 'min_child_samples': 17}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:30,026] Trial 73 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 2.6082469807424492e-05, 'lambda_l2': 4.835054474686707e-07, 'num_leaves': 146, 'feature_fraction': 0.7000138910676379, 'bagging_fraction': 0.942384461251599, 'bagging_freq': 4, 'min_child_samples': 9}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:30,478] Trial 74 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 0.0012014432550951685, 'lambda_l2': 3.593080565250732e-06, 'num_leaves': 188, 'feature_fraction': 0.5343869176394545, 'bagging_fraction': 0.9587140954405055, 'bagging_freq': 4, 'min_child_samples': 13}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:30,821] Trial 75 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 0.00024515613494587864, 'lambda_l2': 1.791016231839514e-06, 'num_leaves': 165, 'feature_fraction': 0.9621816574535709, 'bagging_fraction': 0.9193716690087472, 'bagging_freq': 3, 'min_child_samples': 22}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:31,093] Trial 76 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 0.00015913715772774282, 'lambda_l2': 0.0004159750230410679, 'num_leaves': 99, 'feature_fraction': 0.6463517673768158, 'bagging_fraction': 0.8962939335582638, 'bagging_freq': 4, 'min_child_samples': 33}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:31,541] Trial 77 finished with value: 0.8746928746928747 and parameters: {'lambda_l1': 0.0004700856121482109, 'lambda_l2': 1.233559106544477e-05, 'num_leaves': 133, 'feature_fraction': 0.5823792121410337, 'bagging_fraction': 0.9926624411388671, 'bagging_freq': 3, 'min_child_samples': 8}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:31,992] Trial 78 finished with value: 0.8722358722358723 and parameters: {'lambda_l1': 0.0005662476840891759, 'lambda_l2': 1.4136360375137587e-05, 'num_leaves': 128, 'feature_fraction': 0.571532850627735, 'bagging_fraction': 0.9983732220830364, 'bagging_freq': 4, 'min_child_samples': 7}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:32,383] Trial 79 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 6.049938520889753e-05, 'lambda_l2': 4.146472962284713e-05, 'num_leaves': 139, 'feature_fraction': 0.5890080529917449, 'bagging_fraction': 0.6106771350659391, 'bagging_freq': 5, 'min_child_samples': 10}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:32,812] Trial 80 finished with value: 0.8697788697788698 and parameters: {'lambda_l1': 0.003579207475061002, 'lambda_l2': 9.06955387886433e-05, 'num_leaves': 156, 'feature_fraction': 0.6716118007962936, 'bagging_fraction': 0.971990696545131, 'bagging_freq': 2, 'min_child_samples': 15}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:32,949] Trial 81 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 0.000981410877918352, 'lambda_l2': 7.685593720643963e-06, 'num_leaves': 21, 'feature_fraction': 0.9865431787753319, 'bagging_fraction': 0.8686404703253727, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:33,247] Trial 82 finished with value: 0.855036855036855 and parameters: {'lambda_l1': 1.7178254696338668, 'lambda_l2': 3.0785713668311063e-06, 'num_leaves': 148, 'feature_fraction': 0.6053276826726512, 'bagging_fraction': 0.9307688473160562, 'bagging_freq': 3, 'min_child_samples': 12}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:33,775] Trial 83 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 0.00032077157616691764, 'lambda_l2': 1.2650048622270989e-06, 'num_leaves': 169, 'feature_fraction': 0.7788434769973226, 'bagging_fraction': 0.9561889210400214, 'bagging_freq': 3, 'min_child_samples': 16}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:34,110] Trial 84 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 5.269832363398375e-08, 'lambda_l2': 2.9749234963510085e-07, 'num_leaves': 86, 'feature_fraction': 0.7555766811238002, 'bagging_fraction': 0.9825277789475664, 'bagging_freq': 3, 'min_child_samples': 24}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:34,291] Trial 85 finished with value: 0.8476658476658476 and parameters: {'lambda_l1': 0.008698547994553366, 'lambda_l2': 2.5451054788089946e-05, 'num_leaves': 207, 'feature_fraction': 0.6328978120998049, 'bagging_fraction': 0.6568409282337628, 'bagging_freq': 4, 'min_child_samples': 52}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:34,811] Trial 86 finished with value: 0.8771498771498771 and parameters: {'lambda_l1': 1.2749412968358304e-05, 'lambda_l2': 7.862313681427269e-07, 'num_leaves': 132, 'feature_fraction': 0.490030699367545, 'bagging_fraction': 0.9111679093654695, 'bagging_freq': 3, 'min_child_samples': 9}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:35,318] Trial 87 finished with value: 0.8648648648648649 and parameters: {'lambda_l1': 3.748653903842016e-07, 'lambda_l2': 5.998588950111212e-07, 'num_leaves': 131, 'feature_fraction': 0.4587876068818991, 'bagging_fraction': 0.9111438119082299, 'bagging_freq': 3, 'min_child_samples': 8}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:35,740] Trial 88 finished with value: 0.8648648648648649 and parameters: {'lambda_l1': 2.2916857483100814e-06, 'lambda_l2': 3.6726149508968753e-06, 'num_leaves': 113, 'feature_fraction': 0.40364030036545934, 'bagging_fraction': 0.9381371260633214, 'bagging_freq': 4, 'min_child_samples': 13}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:36,207] Trial 89 finished with value: 0.8697788697788698 and parameters: {'lambda_l1': 1.0198996112792844e-05, 'lambda_l2': 1.3883253208981692e-07, 'num_leaves': 142, 'feature_fraction': 0.4875977205110838, 'bagging_fraction': 0.8920782028624931, 'bagging_freq': 2, 'min_child_samples': 18}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:36,666] Trial 90 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 0.001826617296149474, 'lambda_l2': 0.0010978502641448614, 'num_leaves': 122, 'feature_fraction': 0.6986197041088855, 'bagging_fraction': 0.9493176977586988, 'bagging_freq': 4, 'min_child_samples': 11}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:36,952] Trial 91 finished with value: 0.8722358722358723 and parameters: {'lambda_l1': 1.0178580582255568e-06, 'lambda_l2': 1.8038549195371238e-06, 'num_leaves': 101, 'feature_fraction': 0.44209842325267895, 'bagging_fraction': 0.8779521590505011, 'bagging_freq': 3, 'min_child_samples': 21}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:37,518] Trial 92 finished with value: 0.8648648648648649 and parameters: {'lambda_l1': 0.00011486710584596908, 'lambda_l2': 9.83471427716319e-07, 'num_leaves': 181, 'feature_fraction': 0.5439557436406882, 'bagging_fraction': 0.8464492995394686, 'bagging_freq': 3, 'min_child_samples': 6}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:37,657] Trial 93 finished with value: 0.8525798525798526 and parameters: {'lambda_l1': 0.00045118762721083576, 'lambda_l2': 5.223773897217223e-07, 'num_leaves': 134, 'feature_fraction': 0.5134754864588221, 'bagging_fraction': 0.9146552055715775, 'bagging_freq': 3, 'min_child_samples': 97}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:37,841] Trial 94 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 0.0007881294945872992, 'lambda_l2': 6.586202338276156e-08, 'num_leaves': 150, 'feature_fraction': 0.5753134325544954, 'bagging_fraction': 0.9289574528507376, 'bagging_freq': 3, 'min_child_samples': 67}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:38,524] Trial 95 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 1.2507731849631862e-05, 'lambda_l2': 1.1736534685410375e-05, 'num_leaves': 218, 'feature_fraction': 0.6518464669335136, 'bagging_fraction': 0.8298977068596713, 'bagging_freq': 2, 'min_child_samples': 8}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:39,189] Trial 96 finished with value: 0.8525798525798526 and parameters: {'lambda_l1': 2.228702877658154e-07, 'lambda_l2': 6.3507345836872205e-06, 'num_leaves': 174, 'feature_fraction': 0.916131545007596, 'bagging_fraction': 0.8635607193886283, 'bagging_freq': 5, 'min_child_samples': 10}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:39,603] Trial 97 finished with value: 0.8574938574938575 and parameters: {'lambda_l1': 3.5571380956307694e-06, 'lambda_l2': 2.1095133819939198e-07, 'num_leaves': 196, 'feature_fraction': 0.945507729815427, 'bagging_fraction': 0.9048205683128374, 'bagging_freq': 3, 'min_child_samples': 31}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:39,786] Trial 98 finished with value: 0.8525798525798526 and parameters: {'lambda_l1': 0.003072292751759688, 'lambda_l2': 1.7471099948708764e-08, 'num_leaves': 161, 'feature_fraction': 0.7364670656899249, 'bagging_fraction': 0.9678316085493619, 'bagging_freq': 4, 'min_child_samples': 91}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:40,245] Trial 99 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 6.039177756122719e-07, 'lambda_l2': 2.5087268915208673e-06, 'num_leaves': 116, 'feature_fraction': 0.5279334113485119, 'bagging_fraction': 0.9902155254794532, 'bagging_freq': 3, 'min_child_samples': 16}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:40,750] Trial 100 finished with value: 0.8796068796068796 and parameters: {'lambda_l1': 3.15917821392088e-05, 'lambda_l2': 4.126541099677521e-06, 'num_leaves': 141, 'feature_fraction': 0.6039687063096169, 'bagging_fraction': 0.8865381513224783, 'bagging_freq': 3, 'min_child_samples': 19}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:41,221] Trial 101 finished with value: 0.8648648648648649 and parameters: {'lambda_l1': 0.0002652421549478562, 'lambda_l2': 2.1549489470036513e-05, 'num_leaves': 143, 'feature_fraction': 0.609358746602919, 'bagging_fraction': 0.8894397731608773, 'bagging_freq': 3, 'min_child_samples': 20}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:41,559] Trial 102 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 2.643660848026186e-05, 'lambda_l2': 3.9288381951086796e-06, 'num_leaves': 139, 'feature_fraction': 0.5593405902643612, 'bagging_fraction': 0.8780645548789016, 'bagging_freq': 3, 'min_child_samples': 27}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:42,084] Trial 103 finished with value: 0.8697788697788698 and parameters: {'lambda_l1': 6.223646886619789e-05, 'lambda_l2': 1.074725910594653e-05, 'num_leaves': 125, 'feature_fraction': 0.6249193810781887, 'bagging_fraction': 0.8496913753883186, 'bagging_freq': 3, 'min_child_samples': 12}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:42,637] Trial 104 finished with value: 0.8697788697788698 and parameters: {'lambda_l1': 0.00014525632983022047, 'lambda_l2': 9.77742697251392e-07, 'num_leaves': 156, 'feature_fraction': 0.6647115176974229, 'bagging_fraction': 0.9013578495692843, 'bagging_freq': 2, 'min_child_samples': 14}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:43,071] Trial 105 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 0.00036529464510718724, 'lambda_l2': 2.202000765336461e-06, 'num_leaves': 165, 'feature_fraction': 0.9894860905384096, 'bagging_fraction': 0.8645557090895216, 'bagging_freq': 3, 'min_child_samples': 18}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:43,407] Trial 106 finished with value: 0.8574938574938575 and parameters: {'lambda_l1': 0.0011758649307318637, 'lambda_l2': 5.818087804454613e-06, 'num_leaves': 149, 'feature_fraction': 0.7251516484006003, 'bagging_fraction': 0.8133726580243539, 'bagging_freq': 4, 'min_child_samples': 24}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:43,562] Trial 107 finished with value: 0.8525798525798526 and parameters: {'lambda_l1': 0.0006221834485243241, 'lambda_l2': 1.4148665613046972e-06, 'num_leaves': 134, 'feature_fraction': 0.6782077884130415, 'bagging_fraction': 0.9431392587363493, 'bagging_freq': 3, 'min_child_samples': 84}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:44,258] Trial 108 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 8.004614272021695e-06, 'lambda_l2': 3.548684863692389e-07, 'num_leaves': 185, 'feature_fraction': 0.6947274602955071, 'bagging_fraction': 0.7869014590360595, 'bagging_freq': 4, 'min_child_samples': 9}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:44,536] Trial 109 finished with value: 0.828009828009828 and parameters: {'lambda_l1': 4.03452283334125e-05, 'lambda_l2': 5.4493131240376234e-05, 'num_leaves': 153, 'feature_fraction': 0.9689393373849489, 'bagging_fraction': 0.47005884976433987, 'bagging_freq': 3, 'min_child_samples': 22}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:44,982] Trial 110 finished with value: 0.8697788697788698 and parameters: {'lambda_l1': 1.997652511255197e-05, 'lambda_l2': 0.457663925259537, 'num_leaves': 106, 'feature_fraction': 0.9484967939517495, 'bagging_fraction': 0.9595366244655972, 'bagging_freq': 4, 'min_child_samples': 16}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:45,500] Trial 111 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 0.0005799053936987348, 'lambda_l2': 1.732131052962632e-05, 'num_leaves': 129, 'feature_fraction': 0.4949403068810356, 'bagging_fraction': 0.9874950455236936, 'bagging_freq': 4, 'min_child_samples': 7}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:45,983] Trial 112 finished with value: 0.8746928746928747 and parameters: {'lambda_l1': 0.0016677588622096154, 'lambda_l2': 1.507465289947697e-05, 'num_leaves': 119, 'feature_fraction': 0.5755108921223132, 'bagging_fraction': 0.9999848803116759, 'bagging_freq': 4, 'min_child_samples': 12}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:46,483] Trial 113 finished with value: 0.8648648648648649 and parameters: {'lambda_l1': 0.005636415700465188, 'lambda_l2': 3.207339266472078e-05, 'num_leaves': 109, 'feature_fraction': 0.5817627444303218, 'bagging_fraction': 0.9290419151452405, 'bagging_freq': 4, 'min_child_samples': 12}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:47,391] Trial 114 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 0.0011694048005068448, 'lambda_l2': 7.333596744657259e-07, 'num_leaves': 123, 'feature_fraction': 0.560944400098644, 'bagging_fraction': 0.9762787088250329, 'bagging_freq': 3, 'min_child_samples': 14}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:47,661] Trial 115 finished with value: 0.8476658476658476 and parameters: {'lambda_l1': 8.502341263256861, 'lambda_l2': 8.013596665320607e-06, 'num_leaves': 119, 'feature_fraction': 0.641276406032324, 'bagging_fraction': 0.9995157247917565, 'bagging_freq': 3, 'min_child_samples': 19}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:48,653] Trial 116 finished with value: 0.8697788697788698 and parameters: {'lambda_l1': 0.07472838129677917, 'lambda_l2': 4.545983689949603e-06, 'num_leaves': 139, 'feature_fraction': 0.5971198211977853, 'bagging_fraction': 0.9155735291307013, 'bagging_freq': 4, 'min_child_samples': 10}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:48,992] Trial 117 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 0.001995533515184913, 'lambda_l2': 1.3138731767879268e-05, 'num_leaves': 168, 'feature_fraction': 0.6238537059051328, 'bagging_fraction': 0.964039625516193, 'bagging_freq': 3, 'min_child_samples': 29}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:49,210] Trial 118 finished with value: 0.855036855036855 and parameters: {'lambda_l1': 0.154663094935712, 'lambda_l2': 2.3805800058484546e-06, 'num_leaves': 178, 'feature_fraction': 0.6079331118462431, 'bagging_fraction': 0.9464040216346687, 'bagging_freq': 5, 'min_child_samples': 63}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:49,470] Trial 119 finished with value: 0.8574938574938575 and parameters: {'lambda_l1': 0.0040406795166577116, 'lambda_l2': 4.927069064031802e-07, 'num_leaves': 88, 'feature_fraction': 0.5851653259819608, 'bagging_fraction': 0.8830214288933335, 'bagging_freq': 3, 'min_child_samples': 55}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:50,102] Trial 120 finished with value: 0.8501228501228502 and parameters: {'lambda_l1': 7.92961644543927e-05, 'lambda_l2': 2.100584469194783e-07, 'num_leaves': 157, 'feature_fraction': 0.6570836861144926, 'bagging_fraction': 0.7598927410238566, 'bagging_freq': 6, 'min_child_samples': 5}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:50,588] Trial 121 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 0.0001809460341775824, 'lambda_l2': 1.3947630733730546e-05, 'num_leaves': 127, 'feature_fraction': 0.5406136111837405, 'bagging_fraction': 0.9994255871344886, 'bagging_freq': 4, 'min_child_samples': 7}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:51,050] Trial 122 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 0.00043950414973739925, 'lambda_l2': 6.482393367180433e-06, 'num_leaves': 113, 'feature_fraction': 0.5652529840971658, 'bagging_fraction': 0.9797143841908971, 'bagging_freq': 4, 'min_child_samples': 8}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:51,559] Trial 123 finished with value: 0.8746928746928747 and parameters: {'lambda_l1': 0.0008256784717759347, 'lambda_l2': 3.145553319967844e-05, 'num_leaves': 144, 'feature_fraction': 0.5737627723791888, 'bagging_fraction': 0.9235920332648094, 'bagging_freq': 4, 'min_child_samples': 17}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:52,053] Trial 124 finished with value: 0.8574938574938575 and parameters: {'lambda_l1': 0.0023512425150857387, 'lambda_l2': 3.686415315782036e-05, 'num_leaves': 147, 'feature_fraction': 0.5526834236557416, 'bagging_fraction': 0.9187003169676248, 'bagging_freq': 4, 'min_child_samples': 16}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:52,243] Trial 125 finished with value: 0.8525798525798526 and parameters: {'lambda_l1': 0.0017017178747855024, 'lambda_l2': 0.0001983048162580979, 'num_leaves': 133, 'feature_fraction': 0.7058994476437301, 'bagging_fraction': 0.9064053325842706, 'bagging_freq': 4, 'min_child_samples': 72}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:52,703] Trial 126 finished with value: 0.8525798525798526 and parameters: {'lambda_l1': 0.0009174694216625684, 'lambda_l2': 0.00012965048833183667, 'num_leaves': 211, 'feature_fraction': 0.5208945315593007, 'bagging_fraction': 0.9297463848383374, 'bagging_freq': 3, 'min_child_samples': 21}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:53,220] Trial 127 finished with value: 0.8574938574938575 and parameters: {'lambda_l1': 0.007893502923515648, 'lambda_l2': 2.074536651242457e-05, 'num_leaves': 230, 'feature_fraction': 0.5969867775605068, 'bagging_fraction': 0.8964085984996901, 'bagging_freq': 3, 'min_child_samples': 13}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:53,725] Trial 128 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 1.1767062458744384e-08, 'lambda_l2': 1.1076678230366762e-07, 'num_leaves': 143, 'feature_fraction': 0.9968872573617464, 'bagging_fraction': 0.8308032896325179, 'bagging_freq': 4, 'min_child_samples': 18}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:54,006] Trial 129 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 3.023965136077412, 'lambda_l2': 3.3829479056375044e-06, 'num_leaves': 163, 'feature_fraction': 0.5726609381180879, 'bagging_fraction': 0.868014836018661, 'bagging_freq': 3, 'min_child_samples': 15}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:54,488] Trial 130 finished with value: 0.8697788697788698 and parameters: {'lambda_l1': 0.023829912661644834, 'lambda_l2': 1.230986531032574e-06, 'num_leaves': 138, 'feature_fraction': 0.4745386849016428, 'bagging_fraction': 0.9381809400091123, 'bagging_freq': 4, 'min_child_samples': 11}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:55,036] Trial 131 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 0.0006439404537074271, 'lambda_l2': 1.0079625045767603e-05, 'num_leaves': 130, 'feature_fraction': 0.5714352853042337, 'bagging_fraction': 0.9579274241627987, 'bagging_freq': 4, 'min_child_samples': 6}. Best is trial 71 with value: 0.8820638820638821.
# [I 2024-10-19 19:18:55,487] Trial 132 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 0.0002945649414860307, 'lambda_l2': 6.438957612082369e-05, 'num_leaves': 121, 'feature_fraction': 0.6149938461386792, 'bagging_fraction': 0.9698441408336722, 'bagging_freq': 4, 'min_child_samples': 9}. Best is trial 71 with value: 0.8820638820638821.
# ...
# [I 2024-10-19 19:21:54,330] Trial 457 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 8.663863109149442e-07, 'lambda_l2': 3.073390871078793e-05, 'num_leaves': 202, 'feature_fraction': 0.9376873427141881, 'bagging_fraction': 0.9870190049654487, 'bagging_freq': 4, 'min_child_samples': 15}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:21:54,897] Trial 458 finished with value: 0.8771498771498771 and parameters: {'lambda_l1': 0.00432014306716371, 'lambda_l2': 2.741826012777333e-06, 'num_leaves': 130, 'feature_fraction': 0.9609703672841835, 'bagging_fraction': 0.9027322780298073, 'bagging_freq': 3, 'min_child_samples': 12}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:21:55,566] Trial 459 finished with value: 0.8722358722358723 and parameters: {'lambda_l1': 1.919404253800958e-06, 'lambda_l2': 1.8670831397071423e-05, 'num_leaves': 144, 'feature_fraction': 0.9785097492534026, 'bagging_fraction': 0.7446090747868308, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:21:56,013] Trial 460 finished with value: 0.8501228501228502 and parameters: {'lambda_l1': 3.397066096649773e-07, 'lambda_l2': 5.365098121528748e-06, 'num_leaves': 185, 'feature_fraction': 0.9462226845441915, 'bagging_fraction': 0.7830076340793102, 'bagging_freq': 4, 'min_child_samples': 25}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:21:56,717] Trial 461 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 1.2219943893018143e-06, 'lambda_l2': 1.0466211257676318e-05, 'num_leaves': 173, 'feature_fraction': 0.9283517449034945, 'bagging_fraction': 0.9369186136154474, 'bagging_freq': 3, 'min_child_samples': 10}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:21:57,314] Trial 462 finished with value: 0.8722358722358723 and parameters: {'lambda_l1': 4.191039593911267e-08, 'lambda_l2': 1.8330104077075544e-06, 'num_leaves': 158, 'feature_fraction': 0.9998219483125401, 'bagging_fraction': 0.9993645642554404, 'bagging_freq': 4, 'min_child_samples': 19}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:21:57,899] Trial 463 finished with value: 0.8574938574938575 and parameters: {'lambda_l1': 0.0015427863303229805, 'lambda_l2': 7.742505942902767e-06, 'num_leaves': 198, 'feature_fraction': 0.7179791194910949, 'bagging_fraction': 0.9509415888052152, 'bagging_freq': 3, 'min_child_samples': 16}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:21:58,437] Trial 464 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 9.920850532129293e-08, 'lambda_l2': 0.008282384310099334, 'num_leaves': 147, 'feature_fraction': 0.7053163751332899, 'bagging_fraction': 0.9711564812711789, 'bagging_freq': 4, 'min_child_samples': 13}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:21:58,787] Trial 465 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 0.007650284561911411, 'lambda_l2': 3.663678325766399e-05, 'num_leaves': 138, 'feature_fraction': 0.6438262170195583, 'bagging_fraction': 0.6768140496683613, 'bagging_freq': 3, 'min_child_samples': 22}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:21:59,512] Trial 466 finished with value: 0.8746928746928747 and parameters: {'lambda_l1': 5.950104315915047e-07, 'lambda_l2': 3.4513862506210323e-06, 'num_leaves': 126, 'feature_fraction': 0.9825229963195917, 'bagging_fraction': 0.9822987035729167, 'bagging_freq': 3, 'min_child_samples': 28}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:00,901] Trial 467 finished with value: 0.8796068796068796 and parameters: {'lambda_l1': 2.9457641869755324e-05, 'lambda_l2': 1.4799745447686714e-05, 'num_leaves': 189, 'feature_fraction': 0.9668056246806846, 'bagging_fraction': 0.9528080162801827, 'bagging_freq': 6, 'min_child_samples': 10}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:01,718] Trial 468 finished with value: 0.8697788697788698 and parameters: {'lambda_l1': 3.990346708117361e-05, 'lambda_l2': 2.553317081237662e-05, 'num_leaves': 186, 'feature_fraction': 0.9604692663939207, 'bagging_fraction': 0.9407578444928825, 'bagging_freq': 4, 'min_child_samples': 6}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:02,351] Trial 469 finished with value: 0.8525798525798526 and parameters: {'lambda_l1': 0.00013470177314423492, 'lambda_l2': 0.25866136758768915, 'num_leaves': 191, 'feature_fraction': 0.9671935407541471, 'bagging_fraction': 0.9205257163323697, 'bagging_freq': 6, 'min_child_samples': 8}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:02,973] Trial 470 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 3.023013288428629e-05, 'lambda_l2': 1.470365538244271e-05, 'num_leaves': 177, 'feature_fraction': 0.9729884484690183, 'bagging_fraction': 0.948209915999732, 'bagging_freq': 6, 'min_child_samples': 9}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:03,867] Trial 471 finished with value: 0.8697788697788698 and parameters: {'lambda_l1': 1.831137161212259e-05, 'lambda_l2': 5.575280942599951e-05, 'num_leaves': 189, 'feature_fraction': 0.9513827880665211, 'bagging_fraction': 0.9291935676931858, 'bagging_freq': 7, 'min_child_samples': 10}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:04,427] Trial 472 finished with value: 0.8722358722358723 and parameters: {'lambda_l1': 1.017881569235453e-05, 'lambda_l2': 2.5568755383185645e-05, 'num_leaves': 196, 'feature_fraction': 0.9893568116764858, 'bagging_fraction': 0.9530354022015598, 'bagging_freq': 6, 'min_child_samples': 20}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:05,159] Trial 473 finished with value: 0.8746928746928747 and parameters: {'lambda_l1': 3.121371482768371e-05, 'lambda_l2': 4.350169801204284e-07, 'num_leaves': 184, 'feature_fraction': 0.9566485637651896, 'bagging_fraction': 0.9552901283853469, 'bagging_freq': 6, 'min_child_samples': 14}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:05,728] Trial 474 finished with value: 0.8820638820638821 and parameters: {'lambda_l1': 0.0029666596042969714, 'lambda_l2': 1.4301623845341832e-05, 'num_leaves': 193, 'feature_fraction': 0.9396041797144882, 'bagging_fraction': 0.9165487556090671, 'bagging_freq': 5, 'min_child_samples': 11}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:06,208] Trial 475 finished with value: 0.8746928746928747 and parameters: {'lambda_l1': 6.770196157124516e-05, 'lambda_l2': 1.346738894450009e-05, 'num_leaves': 194, 'feature_fraction': 0.932724279396574, 'bagging_fraction': 0.9014138936215333, 'bagging_freq': 6, 'min_child_samples': 17}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:07,049] Trial 476 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 0.005589827864725263, 'lambda_l2': 1.5246849060176092e-05, 'num_leaves': 207, 'feature_fraction': 0.9160560831667227, 'bagging_fraction': 0.9153174729806989, 'bagging_freq': 6, 'min_child_samples': 11}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:07,916] Trial 477 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 7.566853596759008e-06, 'lambda_l2': 8.116530480682349e-06, 'num_leaves': 200, 'feature_fraction': 0.9472661739548375, 'bagging_fraction': 0.9306611284066406, 'bagging_freq': 6, 'min_child_samples': 15}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:08,770] Trial 478 finished with value: 0.8574938574938575 and parameters: {'lambda_l1': 0.0028187915748108475, 'lambda_l2': 1.0357528560258109e-05, 'num_leaves': 191, 'feature_fraction': 0.9631953377585613, 'bagging_fraction': 0.9056650659065556, 'bagging_freq': 5, 'min_child_samples': 18}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:09,489] Trial 479 finished with value: 0.8648648648648649 and parameters: {'lambda_l1': 2.7637420729156995e-05, 'lambda_l2': 4.9544561834073175e-06, 'num_leaves': 255, 'feature_fraction': 0.894397225046212, 'bagging_fraction': 0.9194415149299678, 'bagging_freq': 6, 'min_child_samples': 23}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:10,264] Trial 480 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 1.9146229183860477e-05, 'lambda_l2': 1.39483831235154e-06, 'num_leaves': 181, 'feature_fraction': 0.9355424113252405, 'bagging_fraction': 0.8913731564946273, 'bagging_freq': 6, 'min_child_samples': 13}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:11,302] Trial 481 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 0.004282717263243234, 'lambda_l2': 2.197870997388781e-06, 'num_leaves': 198, 'feature_fraction': 0.941218725042318, 'bagging_fraction': 0.9294141096543944, 'bagging_freq': 6, 'min_child_samples': 12}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:12,082] Trial 482 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 4.825018617227004e-05, 'lambda_l2': 1.902329729272021e-05, 'num_leaves': 188, 'feature_fraction': 0.9770063032501656, 'bagging_fraction': 0.942447877080512, 'bagging_freq': 5, 'min_child_samples': 16}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:12,980] Trial 483 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 4.6356536890034665e-06, 'lambda_l2': 1.1011812839743546e-05, 'num_leaves': 205, 'feature_fraction': 0.9479058992709086, 'bagging_fraction': 0.9113548956707208, 'bagging_freq': 5, 'min_child_samples': 10}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:13,584] Trial 484 finished with value: 0.855036855036855 and parameters: {'lambda_l1': 3.0614077946390937e-06, 'lambda_l2': 6.286989772327702e-06, 'num_leaves': 195, 'feature_fraction': 0.9674376937757977, 'bagging_fraction': 0.9400233364146231, 'bagging_freq': 6, 'min_child_samples': 21}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:14,357] Trial 485 finished with value: 0.8697788697788698 and parameters: {'lambda_l1': 1.8414355000948107e-07, 'lambda_l2': 3.6421789292683842e-06, 'num_leaves': 175, 'feature_fraction': 0.9896692181462207, 'bagging_fraction': 0.9197704809174384, 'bagging_freq': 5, 'min_child_samples': 14}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:14,992] Trial 486 finished with value: 0.8722358722358723 and parameters: {'lambda_l1': 0.00010690694591694534, 'lambda_l2': 1.9971944777243753e-05, 'num_leaves': 184, 'feature_fraction': 0.9264198364405544, 'bagging_fraction': 0.8890606731829316, 'bagging_freq': 5, 'min_child_samples': 12}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:15,211] Trial 487 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 0.00316431276425063, 'lambda_l2': 0.02610037301450627, 'num_leaves': 190, 'feature_fraction': 0.9568293987024726, 'bagging_fraction': 0.9345811937514642, 'bagging_freq': 2, 'min_child_samples': 73}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:15,521] Trial 488 finished with value: 0.8697788697788698 and parameters: {'lambda_l1': 1.3338905597032986e-05, 'lambda_l2': 1.1019276025606157e-05, 'num_leaves': 180, 'feature_fraction': 0.979321096581424, 'bagging_fraction': 0.9592089746718829, 'bagging_freq': 6, 'min_child_samples': 41}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:16,103] Trial 489 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 2.3385504557422282e-05, 'lambda_l2': 6.092765398043387e-06, 'num_leaves': 202, 'feature_fraction': 0.5342785019689695, 'bagging_fraction': 0.9481557206189842, 'bagging_freq': 3, 'min_child_samples': 18}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:16,959] Trial 490 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 0.009128684447711735, 'lambda_l2': 2.335079983583799e-06, 'num_leaves': 164, 'feature_fraction': 0.9721902379298011, 'bagging_fraction': 0.9032392860293753, 'bagging_freq': 6, 'min_child_samples': 8}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:17,875] Trial 491 finished with value: 0.8501228501228502 and parameters: {'lambda_l1': 3.43736338306012e-07, 'lambda_l2': 6.998334262224845e-07, 'num_leaves': 210, 'feature_fraction': 0.9061134776394928, 'bagging_fraction': 0.8120386185713659, 'bagging_freq': 3, 'min_child_samples': 11}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:18,599] Trial 492 finished with value: 0.8648648648648649 and parameters: {'lambda_l1': 1.8562185710019844e-06, 'lambda_l2': 1.67323006428187e-05, 'num_leaves': 195, 'feature_fraction': 0.6301637734231355, 'bagging_fraction': 0.6920486906127103, 'bagging_freq': 4, 'min_child_samples': 15}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:19,101] Trial 493 finished with value: 0.85995085995086 and parameters: {'lambda_l1': 0.002122607162063232, 'lambda_l2': 3.879431735813946e-06, 'num_leaves': 169, 'feature_fraction': 0.9904845725863973, 'bagging_fraction': 0.963094559949956, 'bagging_freq': 3, 'min_child_samples': 19}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:21,054] Trial 494 finished with value: 0.8697788697788698 and parameters: {'lambda_l1': 0.00024797653953734813, 'lambda_l2': 1.4764290939609088e-06, 'num_leaves': 190, 'feature_fraction': 0.9997799515036903, 'bagging_fraction': 0.9308904781961449, 'bagging_freq': 2, 'min_child_samples': 5}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:22,151] Trial 495 finished with value: 0.8746928746928747 and parameters: {'lambda_l1': 0.00038298880236856413, 'lambda_l2': 7.960881324042706e-06, 'num_leaves': 156, 'feature_fraction': 0.9613355341158374, 'bagging_fraction': 0.916009730229906, 'bagging_freq': 4, 'min_child_samples': 14}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:22,593] Trial 496 finished with value: 0.8574938574938575 and parameters: {'lambda_l1': 6.944192945920196e-06, 'lambda_l2': 2.4079389712653178e-05, 'num_leaves': 185, 'feature_fraction': 0.9424971984365893, 'bagging_fraction': 0.9662502919910302, 'bagging_freq': 3, 'min_child_samples': 50}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:23,417] Trial 497 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 4.510118806961455e-07, 'lambda_l2': 1.1626722434376475e-05, 'num_leaves': 201, 'feature_fraction': 0.9818265538880457, 'bagging_fraction': 0.6463356201897276, 'bagging_freq': 4, 'min_child_samples': 10}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:23,789] Trial 498 finished with value: 0.8624078624078624 and parameters: {'lambda_l1': 0.013124665936635681, 'lambda_l2': 5.111148873012521e-06, 'num_leaves': 216, 'feature_fraction': 0.9636019643038919, 'bagging_fraction': 0.4925850195954696, 'bagging_freq': 3, 'min_child_samples': 25}. Best is trial 133 with value: 0.8845208845208845.
# [I 2024-10-19 19:22:24,647] Trial 499 finished with value: 0.8673218673218673 and parameters: {'lambda_l1': 0.001039119361460644, 'lambda_l2': 3.4289043214937186e-05, 'num_leaves': 172, 'feature_fraction': 0.4844778790139489, 'bagging_fraction': 0.9436313500670198, 'bagging_freq': 5, 'min_child_samples': 7}. Best is trial 133 with value: 0.8845208845208845.
# Number of finished trials: 500
# Best trial:
#   Value: 0.8845208845208845
#   Params:
#     lambda_l1: 1.2475923812257981e-06
#     lambda_l2: 1.6659498563207172e-05
#     num_leaves: 193
#     feature_fraction: 0.9820699825542016
#     bagging_fraction: 0.9894582141957871
#     bagging_freq: 4
#     min_child_samples: 13

# %%
optuna.visualization.plot_param_importances(study)

# %% [markdown]
# ### Quantification of Final Model Performance and Explanation of Predictions using SHAP values

# %%
import shap

# %%
# This function uses the best trial hyperparameters and evaluates the model
def detailed_objectivelgb(trial): 
    dtrain = lgb.Dataset(X_train, label=y_train)

    param = {
        "objective": "binary",
        "metric": "binary_logloss",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
    }

    gbm = lgb.train(param, dtrain)
    preds = gbm.predict(X_test)
    pred_labels = np.rint(preds)
    accuracy = sklearn.metrics.accuracy_score(y_test, pred_labels)
    print('Final accuracy:',accuracy)
    print('Confusion Matrix:\n',sklearn.metrics.confusion_matrix(y_test, pred_labels))
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, preds)
    
    roc_auc = sklearn.metrics.auc(fpr, tpr)
    display = sklearn.metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc,
                                  estimator_name='lightgbm')
    display.plot() 
    plt.show()
    explainer = shap.TreeExplainer(gbm)
    shap_values = explainer(X)
    shap.summary_plot(shap_values, X)

# %%
detailed_objectivelgb(study.best_trial)
# Out:
# Final accuracy: 0.8612334801762115
# Confusion Matrix:
#  [[367  20]
#  [ 43  24]]

# %% [markdown]
# <h1>Anomaly Detection</h1>
# <h5>Isolation Forest is an algorithm specifically designed for anomaly detection. Unlike many other techniques, it doesn’t rely on distance or density calculations but instead focuses on isolating anomalies. The key idea is that anomalies are more easily isolated than normal points due to their rarity and dissimilarity to the majority of the data</h5><br>
# <h5>The other method we used is the Z score normalization method, we normalized all the values and compared them with an acceptable threshold and find out all the anomalies.<h5>

# %%
from sklearn.ensemble import IsolationForest
iso_forest = IsolationForest(n_estimators=100, contamination=0.1, random_state=42)
iso_forest.fit(df4)

# Predicting the anomalies
df4['anomaly'] = iso_forest.predict(df4)
# df4['anomaly'] = df4['anomaly'].map({1: 'Normal', -1: 'Anomaly'})

df4.head()
# Out:
#           Name  Relative Velocity km per hr  Miss Dist.(kilometers)  \
# 27  2162173.00                     48873.91             52470692.00
# 55  3648769.00                     39036.73             46063436.00
# 73  2154244.00                     58051.77             45024037.85
# 88  3414393.00                     66663.09             48037404.00
# 111 3761271.00                     56981.95             49979660.00
#
#      Jupiter Tisserand Invariant  Semi Major Axis  Asc Node Longitude  \
# 27                          5.31             1.19                4.39
# 55                          6.38             0.94                3.56
# 73                          3.37             2.31                3.72
# 88                          4.57             1.38                1.85
# 111                         7.18             0.80                3.60
#
#      Perihelion Arg  Aphelion Dist  Perihelion Time  Mean Anomaly  \
# 27             3.69           1.42       2457797.75          2.69
# 55             0.41           1.17       2458103.64          4.32
# 73             1.71           3.57       2457601.27          1.96
# 88             4.26           1.72       2457658.84          5.66
# 111            5.72           1.10       2458032.74          5.51
#
#      Orbital Period  Orbit Uncertainity  Hazardous         Approach Date  \
# 27             0.00                0.00       1.00 794448333333333376.00
# 55             0.00                0.00       0.00 799916000000000000.00
# 73             2.00                0.00       0.00 803200000000000000.00
# 88             0.00                0.00       0.00 805792000000000000.00
# 111            0.00                1.00       0.00 809809500000000000.00
#
#      Time Until Approach(days)  Miss Distance vs Semi Major Axis(AU)  \
# 27                    10820.00                                  0.29
# 55                    10757.00                                  0.33
# 73                    10719.00                                  0.13
# 88                    10689.00                                  0.23
# 111                   10643.00                                  0.42
#
#      Eccentricity  Orbital Period(days)  Orbital Velocity(km/s)  \
# 27           0.19                473.82                   27.31
# 55           0.25                330.30                   30.80
# 73           0.55               1279.46                   19.61
# 88           0.25                589.76                   25.39
# 111          0.36                263.53                   33.21
#
#      Escape Velocity(km/s)  Specific Orbital Energy (J/kg)  \
# 27                   38.63                   -372991163.21
# 55                   43.56                   -474430611.60
# 73                   27.74                   -192349248.96
# 88                   35.91                   -322347505.04
# 111                  46.97                   -551509530.58
#
#        Specific Angular Momentum(kgm/s)  Perihelion Velocity (km/s)  \
# 27  22768569622802589062694615121920.00                       33.11
# 55  17436288536993624517360792633344.00                       39.66
# 73  32032905788560893182762121428992.00                       36.32
# 88  25658349180291486364876043976704.00                       32.70
# 111 13879448656573793406457858752512.00                       48.54
#
#      Aphelion Velocity (km/s)  Synodic Period(days)  Mean Motion(rads/days)  \
# 27                      22.53               1594.01                    0.01
# 55                      23.93               3451.35                    0.02
# 73                      10.59                511.18                    0.00
# 88                      19.72                959.47                    0.01
# 111                     22.72                946.28                    0.02
#
#      Mean Longitude  Precession Rate  Eccentric Anomaly  True Anomaly  \
# 27            10.77             0.00               2.76          2.82
# 55             8.30             0.00               4.12         -2.36
# 73             7.39             0.00               2.35          2.70
# 88            11.77             0.00               5.48         -1.00
# 111           14.84             0.00               5.19         -1.45
#
#      Heliocentric Distance  anomaly
# 27                    1.40        1
# 55                    1.07        1
# 73                    3.20       -1
# 88                    1.14        1
# 111                   0.67        1

# %%
z_scores = np.abs((df4 - df4.mean()) / df4.std())

threshold = 3

anomalies = (z_scores > threshold).any(axis=1)

df4['anomaly_z_scores'] = anomalies.astype(int)

print(f"Number of anomalies detected: {sum(df4['anomaly_z_scores'] == 1)}")
# Out:
# Number of anomalies detected: 437

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(df4['anomaly'], df4['anomaly_z_scores'])

# Plotting the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Method 1 (Isolation Forest)')
plt.ylabel('Method 2 (Z-Score)')
plt.title('Confusion Matrix of Anomaly Detection Methods')
plt.show()


df4['anomaly_both'] = ((df4['anomaly'] == 1) & (df4['anomaly_z_scores'] == 1)).astype(int)

num_common_anomalies = df4['anomaly_both'].sum()

print(f"Number of anomalies flagged by both methods: {num_common_anomalies}") #Total of 205 anomalies detected from the intersection of both methods
# Out:
# Number of anomalies flagged by both methods: 205
